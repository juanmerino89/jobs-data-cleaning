# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Files Loading

# %% [markdown]
# We load all the files in the folder "data":

# %%
folder = 'data_jobs'
files = os.listdir(folder)

dfs = []

headers = ['Job','URL','Company','Location','Salary','Posted','ID','Job_Description']

for file in files:
    path = os.path.join(folder, file)
    
    df = pd.read_excel(path, names=headers)
    df.dropna(subset=['Company'], inplace=True)
    dfs.append(df)

Jobs = pd.concat(dfs)

# %% [markdown]
# # Data Cleaning
#
# First of all, we need to delete all the duplicated values we could have. The best column to do so is the "ID" column:

# %%
Jobs = Jobs.drop_duplicates(subset='ID')

# %% [markdown]
# Let's see how it looks like the df:

# %%
Jobs.describe()
# Out:
#                       Job                                                URL  \
# count              146392                                             146392
# unique              62951                                             146392
# top     Financial Analyst  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# freq                 4081                                                  1
#
#                     Company Location                        Salary     Posted  \
# count                146392   146366                         76339     132123
# unique                40437    33485                         21898        340
# top     JPMorgan Chase & Co   Remote  Pay information not provided  PostedHoy
# freq                    664     8358                          8971      40498
#
#                          ID                                    Job_Description
# count                146392                                             146392
# unique               146392                                             144673
# top     sj_cd2707991b8bc653  La página que solicitaste no fue encontrada._x...
# freq                      1                                                 26

# %%
Jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146392 entries, 0 to 987
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Job              146392 non-null  object
#  1   URL              146392 non-null  object
#  2   Company          146392 non-null  object
#  3   Location         146366 non-null  object
#  4   Salary           76339 non-null   object
#  5   Posted           132123 non-null  object
#  6   ID               146392 non-null  object
#  7   Job_Description  146392 non-null  object
# dtypes: object(8)
# memory usage: 10.1+ MB

# %% [markdown]
# We see we have almost all the columns with non-null values, except Salary and Posted. The column Posted is not critic, since it's a column that shows when the job posting was published in terms of the extraction date. It doesn't seem very useful, so we can't drop it.
#
# With regards to the Salary column, we see we have aprox 30-35% of non-null values.
# #### Could we estimate the Salary null values?
# Let's see it later!

# %%
Jobs.drop(columns=['Posted'])
# Out:
#                                                    Job  \
# 0              Market Development Representative 16702
# 1                     Vice President, Quality Services
# 2                                     Business Analyst
# 3    Corporate Strategy and Business Development Ma...
# 4                  Data Analyst, Business Intelligence
# ..                                                 ...
# 969         Property Controller- Graduate East Lansing
# 972                               Assistant Controller
# 980                                   Plant Controller
# 981                                         Controller
# 987                                   Plant Controller
#
#                                                    URL  \
# 0    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2    https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ..                                                 ...
# 969  https://www.indeed.com/rc/clk?jk=a88f74a87f1c6...
# 972  https://www.indeed.com/rc/clk?jk=6fe37642cf957...
# 980  https://www.indeed.com/rc/clk?jk=094beaf0996c9...
# 981  https://www.indeed.com/rc/clk?jk=f3027b081096f...
# 987  https://www.indeed.com/rc/clk?jk=f6fc5130f7639...
#
#                               Company                            Location  \
# 0            Corps Team Services, LLC                             Arizona
# 1             Family Support Services               Tampa, FL+2 locations
# 2                         Leonardo247                              Remote
# 3                 United Therapeutics          Research Triangle Park, NC
# 4                       Land O' Frost  Madisonville, KY 42431+2 locations
# ..                                ...                                 ...
# 969                 Schulte Companies  East Lansing, MI 48823+1 ubicación
# 972  Home State Insurance Group, Inc.          Waco, TX 76710+1 ubicación
# 980               Dometic Corporation                  Cerritos, CA 90703
# 981             The Talance Group, LP   Houston, TX 77002 (Downtown area)
# 987                  Johnson Controls         Marinette, WI+5 ubicaciones
#
#                          Salary                    ID  \
# 0      $26.17 - $28.17 por hora   sj_cd2707991b8bc653
# 1                           NaN   sj_aa0f5247ff3deca7
# 2                           NaN  job_bd203b586ac89e05
# 3                           NaN   sj_8cb506d1ac43bc43
# 4    $89,100 - $108,900 por año   sj_bdfad91ca716ac0f
# ..                          ...                   ...
# 969                         NaN  job_a88f74a87f1c6e48
# 972                         NaN  job_6fe37642cf95726f
# 980                         NaN  job_094beaf0996c95fe
# 981                         NaN  job_f3027b081096ff4c
# 987                         NaN  job_f6fc5130f7639a6e
#
#                                        Job_Description
# 0    Iniciar sesión_x000D_\nInicio del contenido pr...
# 1    Iniciar sesión_x000D_\nInicio del contenido pr...
# 2    Iniciar sesión_x000D_\nInicio del contenido pr...
# 3    Iniciar sesión_x000D_\nInicio del contenido pr...
# 4    Iniciar sesión_x000D_\nInicio del contenido pr...
# ..                                                 ...
# 969  Ir directamente al contenido principal_x000D_\...
# 972  Ir directamente al contenido principal_x000D_\...
# 980  Ir directamente al contenido principal_x000D_\...
# 981  Ir directamente al contenido principal_x000D_\...
# 987  Ir directamente al contenido principal_x000D_\...
#
# [146392 rows x 7 columns]

# %% [markdown]
# We saw all the Dtypes are object. However, the Salary column would be interesting to be a numeric column.

# %% [markdown]
# ## Salary

# %% [markdown]
# Let's see how it looks like:

# %%
Jobs['Salary'].head(50).values.tolist()
# Out:
# ['$26.17 - $28.17 por hora',
#  nan,
#  nan,
#  nan,
#  '$89,100 - $108,900 por año',
#  '$58,723 - $131,682 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '$80,000 - $120,000 por año',
#  nan,
#  nan,
#  '$63,108 - $95,512 por año',
#  nan,
#  nan,
#  '$58,760 - $90,000 por año',
#  nan,
#  '$80,000 - $125,000 por año',
#  nan,
#  nan,
#  nan,
#  '$55,843 - $83,765 por año',
#  nan,
#  '$53,000 - $62,000 por año',
#  '$90,806 - $114,444 por año',
#  nan,
#  nan,
#  nan,
#  '$49 - $53 por hora',
#  nan,
#  '$71,052 - $113,807 por año',
#  '$75,157 - $127,767 por año',
#  nan,
#  nan,
#  '$65,395 - $101,150 por año',
#  nan,
#  nan,
#  '$41.18 - $52.00 por hora',
#  '$115,000 - $120,000 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Hasta $57 por hora',
#  '$45 - $60 por hora',
#  nan,
#  'Hasta $40 por hora']

# %% [markdown]
# It looks horrible! We have single values, we have ranges, we have salary per year (año), month (mes), week (semana), day (día), and hourly (hora). Moreover we have the $ symbol in all the values, and in some cases we have the words Desde (From), and Hasta (Up to). Let's clean it!
#
# First of all, the frecuency pay could be interesting in order to standardize the salaries. Let's split it into a new column:

# %%
Jobs['Frecuency_Salary'] = Jobs['Salary'].str.split(' por ').str.get(1)

# %%
Jobs['Frecuency_Salary'].unique()
# Out:
# array(['hora', nan, 'año', 'mes', 'día', 'semana'], dtype=object)

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0            Market Development Representative 16702
# 1                   Vice President, Quality Services
# 2                                   Business Analyst
# 3  Corporate Strategy and Business Development Ma...
# 4                Data Analyst, Business Intelligence
#
#                                                  URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     Company                            Location  \
# 0  Corps Team Services, LLC                             Arizona
# 1   Family Support Services               Tampa, FL+2 locations
# 2               Leonardo247                              Remote
# 3       United Therapeutics          Research Triangle Park, NC
# 4             Land O' Frost  Madisonville, KY 42431+2 locations
#
#                        Salary Posted                    ID  \
# 0    $26.17 - $28.17 por hora    NaN   sj_cd2707991b8bc653
# 1                         NaN    NaN   sj_aa0f5247ff3deca7
# 2                         NaN    NaN  job_bd203b586ac89e05
# 3                         NaN    NaN   sj_8cb506d1ac43bc43
# 4  $89,100 - $108,900 por año    NaN   sj_bdfad91ca716ac0f
#
#                                      Job_Description Frecuency_Salary
# 0  Iniciar sesión_x000D_\nInicio del contenido pr...             hora
# 1  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 2  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 3  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 4  Iniciar sesión_x000D_\nInicio del contenido pr...              año

# %% [markdown]
# Nice! Now let's delete the words "Desde " and "Hasta ":

# %%
Jobs['Salary'] = Jobs['Salary'].str.replace('Desde ','')
Jobs['Salary'] = Jobs['Salary'].str.replace('Hasta ','')

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0            Market Development Representative 16702
# 1                   Vice President, Quality Services
# 2                                   Business Analyst
# 3  Corporate Strategy and Business Development Ma...
# 4                Data Analyst, Business Intelligence
#
#                                                  URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     Company                            Location  \
# 0  Corps Team Services, LLC                             Arizona
# 1   Family Support Services               Tampa, FL+2 locations
# 2               Leonardo247                              Remote
# 3       United Therapeutics          Research Triangle Park, NC
# 4             Land O' Frost  Madisonville, KY 42431+2 locations
#
#                        Salary Posted                    ID  \
# 0    $26.17 - $28.17 por hora    NaN   sj_cd2707991b8bc653
# 1                         NaN    NaN   sj_aa0f5247ff3deca7
# 2                         NaN    NaN  job_bd203b586ac89e05
# 3                         NaN    NaN   sj_8cb506d1ac43bc43
# 4  $89,100 - $108,900 por año    NaN   sj_bdfad91ca716ac0f
#
#                                      Job_Description Frecuency_Salary
# 0  Iniciar sesión_x000D_\nInicio del contenido pr...             hora
# 1  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 2  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 3  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 4  Iniciar sesión_x000D_\nInicio del contenido pr...              año

# %% [markdown]
# Let's work on the range values. An interesting approach would be to have two new columns, for the low part of the range, and another for the high part of the range:

# %%
salary_split = Jobs['Salary'].str.split('-', expand=True)
Jobs['Low_Salary'] = salary_split[0].str.strip()
Jobs['High_Salary'] = salary_split[1].str.strip()

# %% [markdown]
# With these split, all the non-range values, will have value only in the Low_Salary column. In this cases, let's set the same values for all low and high salary columns:

# %%
Jobs['High_Salary'] = Jobs['High_Salary'].fillna(Jobs['Low_Salary'])

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0            Market Development Representative 16702
# 1                   Vice President, Quality Services
# 2                                   Business Analyst
# 3  Corporate Strategy and Business Development Ma...
# 4                Data Analyst, Business Intelligence
#
#                                                  URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     Company                            Location  \
# 0  Corps Team Services, LLC                             Arizona
# 1   Family Support Services               Tampa, FL+2 locations
# 2               Leonardo247                              Remote
# 3       United Therapeutics          Research Triangle Park, NC
# 4             Land O' Frost  Madisonville, KY 42431+2 locations
#
#                        Salary Posted                    ID  \
# 0    $26.17 - $28.17 por hora    NaN   sj_cd2707991b8bc653
# 1                         NaN    NaN   sj_aa0f5247ff3deca7
# 2                         NaN    NaN  job_bd203b586ac89e05
# 3                         NaN    NaN   sj_8cb506d1ac43bc43
# 4  $89,100 - $108,900 por año    NaN   sj_bdfad91ca716ac0f
#
#                                      Job_Description Frecuency_Salary  \
# 0  Iniciar sesión_x000D_\nInicio del contenido pr...             hora
# 1  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 2  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 3  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 4  Iniciar sesión_x000D_\nInicio del contenido pr...              año
#
#   Low_Salary       High_Salary
# 0     $26.17   $28.17 por hora
# 1        NaN               NaN
# 2        NaN               NaN
# 3        NaN               NaN
# 4    $89,100  $108,900 por año

# %% [markdown]
# We see how it looks better, but we need to clean the non numeric values for both columns. So let's replace all the non numeric strings:

# %%
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace('[\$,]', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace('[\$,]', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por hora', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por hora', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por día', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por día', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por año', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por año', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por mes', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por mes', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por semana', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por semana', '', regex=True)
Jobs['Low_Salary'] = pd.to_numeric(Jobs['Low_Salary'], errors='coerce')
Jobs['High_Salary'] = pd.to_numeric(Jobs['High_Salary'], errors='coerce')

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0            Market Development Representative 16702
# 1                   Vice President, Quality Services
# 2                                   Business Analyst
# 3  Corporate Strategy and Business Development Ma...
# 4                Data Analyst, Business Intelligence
#
#                                                  URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     Company                            Location  \
# 0  Corps Team Services, LLC                             Arizona
# 1   Family Support Services               Tampa, FL+2 locations
# 2               Leonardo247                              Remote
# 3       United Therapeutics          Research Triangle Park, NC
# 4             Land O' Frost  Madisonville, KY 42431+2 locations
#
#                        Salary Posted                    ID  \
# 0    $26.17 - $28.17 por hora    NaN   sj_cd2707991b8bc653
# 1                         NaN    NaN   sj_aa0f5247ff3deca7
# 2                         NaN    NaN  job_bd203b586ac89e05
# 3                         NaN    NaN   sj_8cb506d1ac43bc43
# 4  $89,100 - $108,900 por año    NaN   sj_bdfad91ca716ac0f
#
#                                      Job_Description Frecuency_Salary  \
# 0  Iniciar sesión_x000D_\nInicio del contenido pr...             hora
# 1  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 2  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 3  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 4  Iniciar sesión_x000D_\nInicio del contenido pr...              año
#
#    Low_Salary  High_Salary
# 0       26.17        28.17
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4    89100.00    108900.00

# %% [markdown]
# Good! Now we need to standardize the Salaries, into a unique frecuency. The most common is to show the salary yearly. So let's transform all the non-yearly salaries into a yearly:

# %%
Jobs['Low_Salary'] = Jobs['Low_Salary'].astype(float)
Jobs['High_Salary'] = Jobs['High_Salary'].astype(float)

# %%
def transform_salary(row):
    if row['Frecuency_Salary'] == 'año':
        factor = 1
    elif row['Frecuency_Salary'] == 'mes':
        factor = 12
    elif row['Frecuency_Salary'] == 'semana':
        factor = 49
    elif row['Frecuency_Salary'] == 'día':
        factor = 230
    elif row['Frecuency_Salary'] == 'hora':
        factor = 1840
    else:
        factor = 1
    row['Low_Salary'] *= factor
    row['High_Salary'] *= factor
    return row

Jobs = Jobs.apply(transform_salary, axis=1)

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0            Market Development Representative 16702
# 1                   Vice President, Quality Services
# 2                                   Business Analyst
# 3  Corporate Strategy and Business Development Ma...
# 4                Data Analyst, Business Intelligence
#
#                                                  URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     Company                            Location  \
# 0  Corps Team Services, LLC                             Arizona
# 1   Family Support Services               Tampa, FL+2 locations
# 2               Leonardo247                              Remote
# 3       United Therapeutics          Research Triangle Park, NC
# 4             Land O' Frost  Madisonville, KY 42431+2 locations
#
#                        Salary Posted                    ID  \
# 0    $26.17 - $28.17 por hora    NaN   sj_cd2707991b8bc653
# 1                         NaN    NaN   sj_aa0f5247ff3deca7
# 2                         NaN    NaN  job_bd203b586ac89e05
# 3                         NaN    NaN   sj_8cb506d1ac43bc43
# 4  $89,100 - $108,900 por año    NaN   sj_bdfad91ca716ac0f
#
#                                      Job_Description Frecuency_Salary  \
# 0  Iniciar sesión_x000D_\nInicio del contenido pr...             hora
# 1  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 2  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 3  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 4  Iniciar sesión_x000D_\nInicio del contenido pr...              año
#
#    Low_Salary  High_Salary
# 0     48152.8      51832.8
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4     89100.0     108900.0

# %% [markdown]
# Nice! The last step here, is to create a unique column with salaries. The purpose of this is to compare and analyze, since some of the salaries are ranges and some others are not. The best approach for this is to have a mean salary column:

# %%
Jobs['Mean_Salary'] = (Jobs['Low_Salary'] + Jobs['High_Salary']) / 2

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0            Market Development Representative 16702
# 1                   Vice President, Quality Services
# 2                                   Business Analyst
# 3  Corporate Strategy and Business Development Ma...
# 4                Data Analyst, Business Intelligence
#
#                                                  URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     Company                            Location  \
# 0  Corps Team Services, LLC                             Arizona
# 1   Family Support Services               Tampa, FL+2 locations
# 2               Leonardo247                              Remote
# 3       United Therapeutics          Research Triangle Park, NC
# 4             Land O' Frost  Madisonville, KY 42431+2 locations
#
#                        Salary Posted                    ID  \
# 0    $26.17 - $28.17 por hora    NaN   sj_cd2707991b8bc653
# 1                         NaN    NaN   sj_aa0f5247ff3deca7
# 2                         NaN    NaN  job_bd203b586ac89e05
# 3                         NaN    NaN   sj_8cb506d1ac43bc43
# 4  $89,100 - $108,900 por año    NaN   sj_bdfad91ca716ac0f
#
#                                      Job_Description Frecuency_Salary  \
# 0  Iniciar sesión_x000D_\nInicio del contenido pr...             hora
# 1  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 2  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 3  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 4  Iniciar sesión_x000D_\nInicio del contenido pr...              año
#
#    Low_Salary  High_Salary  Mean_Salary
# 0     48152.8      51832.8      49992.8
# 1         NaN          NaN          NaN
# 2         NaN          NaN          NaN
# 3         NaN          NaN          NaN
# 4     89100.0     108900.0      99000.0

# %% [markdown]
# PERFECT!

# %% [markdown]
# ## Jobs Group
#
# Since the Job names are quite heterogeneus, it's mandatory to group them in a few job groups. Let's do it with the dictionary categories.xlsx:

# %%
category_df = pd.read_excel('master_data\categories.xlsx')

category_df.head()
# Out:
#             keyword        category
# 0     data engineer   Data Engineer
# 1    data scientist  Data Scientist
# 2      data science  Data Scientist
# 3               ds   Data Scientist
# 4  machine learning  ML/AI Engineer

# %%
categories = category_df.set_index('keyword')['category'].to_dict()

def assign_category(job):
    job = job.lower()
    for keyword, category in categories.items():
        if keyword in job:
            return category
    return 'Others'

Jobs['Jobs_Group'] = Jobs['Job'].apply(assign_category)

# %%
category_counts = Jobs['Jobs_Group'].value_counts()

print(category_counts)
# Out:
# Financial Analyst            24931
# Business Analyst             22309
# Data Analyst                 16786
# Data Engineer                14098
# Controller                   13592
# Data Scientist                9797
# Business Intelligence         8337
# CFO                           7663
# Analyst                       7510
# Finance                       7495
# Operations Analyst            4945
# ML/AI Engineer                3878
# Others                        3814
# Statistician/Mathemathics     1237
# Name: Jobs_Group, dtype: int64

# %% [markdown]
# Nice!

# %% [markdown]
# ## Location

# %% [markdown]
# The next step would be to clean the Location column. Would be nice to have a City and State column. The best way to split it, is to split it two columns by comma, getting all the string before, and the two letters after comma. The first column will be the city, and the second one the state. Let's work on it!

# %%
Jobs[['City', 'State']] = Jobs['Location'].str.extract(r'^(.+),\s([A-Z]{2})', expand=True)

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0            Market Development Representative 16702
# 1                   Vice President, Quality Services
# 2                                   Business Analyst
# 3  Corporate Strategy and Business Development Ma...
# 4                Data Analyst, Business Intelligence
#
#                                                  URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/rc/clk?jk=bd203b586ac89...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     Company                            Location  \
# 0  Corps Team Services, LLC                             Arizona
# 1   Family Support Services               Tampa, FL+2 locations
# 2               Leonardo247                              Remote
# 3       United Therapeutics          Research Triangle Park, NC
# 4             Land O' Frost  Madisonville, KY 42431+2 locations
#
#                        Salary Posted                    ID  \
# 0    $26.17 - $28.17 por hora    NaN   sj_cd2707991b8bc653
# 1                         NaN    NaN   sj_aa0f5247ff3deca7
# 2                         NaN    NaN  job_bd203b586ac89e05
# 3                         NaN    NaN   sj_8cb506d1ac43bc43
# 4  $89,100 - $108,900 por año    NaN   sj_bdfad91ca716ac0f
#
#                                      Job_Description Frecuency_Salary  \
# 0  Iniciar sesión_x000D_\nInicio del contenido pr...             hora
# 1  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 2  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 3  Iniciar sesión_x000D_\nInicio del contenido pr...              NaN
# 4  Iniciar sesión_x000D_\nInicio del contenido pr...              año
#
#    Low_Salary  High_Salary  Mean_Salary        Jobs_Group  \
# 0     48152.8      51832.8      49992.8      Data Analyst
# 1         NaN          NaN          NaN               CFO
# 2         NaN          NaN          NaN  Business Analyst
# 3         NaN          NaN          NaN  Business Analyst
# 4     89100.0     108900.0      99000.0      Data Analyst
#
#                      City State
# 0                     NaN   NaN
# 1                   Tampa    FL
# 2                     NaN   NaN
# 3  Research Triangle Park    NC
# 4            Madisonville    KY

# %%
Jobs['City'].values
# Out:
# array([nan, 'Tampa', nan, ..., 'Cerritos', 'Houston', 'Marinette'],
#       dtype=object)

# %%
Jobs['State'].values
# Out:
# array([nan, 'FL', nan, ..., 'CA', 'TX', 'WI'], dtype=object)

# %% [markdown]
# Nice! Now a minor problem, is that there is some Locations, that are directy the state (e.g. California). In this cases, let's create a function, using the dictionary states.xlsx:

# %%
states_df = pd.read_excel('master_data\states.xlsx')

states_df.head()
# Out:
#         State Code
# 0     Alabama   AL
# 1      Alaska   AK
# 2     Arizona   AZ
# 3    Arkansas   AR
# 4  California   CA

# %%
states_dict = states_df.set_index('State')['Code'].to_dict()

def assign_state(row):
    if pd.isnull(row['State']):
        location = str(row['Location'])
        for state, code in states_dict.items():
            if state.lower() in location.lower():
                return code
    return row['State']

Jobs['State'] = Jobs.apply(assign_state, axis=1)

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Remote
#
# An interesting column would be if a job is remote or hybrid or none of these. In order to do so, we can use a dictionary with keywords:

# %%
remote_df = pd.read_excel('master_data/remote.xlsx')

remote_df.head()
# Out:
#             Value Category
# 0          Hybrid   Hybrid
# 1          hybrid   Hybrid
# 2          Remote   Remote
# 3          remote   Remote
# 4  Work From Home   Remote

# %%
remote_dict = remote_df.set_index('Value')['Category'].to_dict()

def assign_remote(row):
    for col in ['Job', 'Location', 'Job_Description']:
        col_value = str(row[col])
        for value, category in remote_dict.items():
            if value.lower() in col_value.lower():
                return category
    return None

Jobs['Remote'] = Jobs.apply(assign_remote, axis=1)

# %%
remote_counts = Jobs['Remote'].value_counts()

print(remote_counts)
# Out:
# Remote    29600
# Hybrid    27393
# Name: Remote, dtype: int64

# %% [markdown]
# Looks great!

# %% [markdown]
# ## Profile
#
# Another interesting column is the profile. In this column we will show if it's a Lead, Senior or a Junior position. As we did in the remote column, we will use a dictionary:

# %%
profile_df = pd.read_excel('master_data\profile.xlsx')

profile_df.head()
# Out:
#     Value Profile
# 0  junior  Junior
# 1  Junior  Junior
# 2      Jr  Junior
# 3     Jr.  Junior
# 4  senior  Senior

# %%
profile_dict = profile_df.set_index('Value')['Profile'].to_dict()

def assign_profile(row):
    for col in ['Job']:
        for value, profile in profile_dict.items():
            if value.lower() in row[col].lower():
                return profile
    return None

Jobs['Profile'] = Jobs.apply(assign_profile, axis=1)

# %%
profile_counts = Jobs['Profile'].value_counts()

print(profile_counts)
# Out:
# Senior    28842
# Lead      23333
# Junior     1738
# Name: Profile, dtype: int64

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Skills
#
# Now, let's deep into the job descriptions. Would be nice to have a Skills column. We can have it using a dictionary skills.xlsx:

# %%
skills_df = pd.read_excel('master_data\skills.xlsx')

skills_df.head()
# Out:
#                 Skills            Group
# 0               Access           Access
# 1      Adobe Analytics  Adobe Analytics
# 2                  AWS              AWS
# 3  Amazon Web Services              AWS
# 4           Amazon Web              AWS

# %%
skills_dict = skills_df.set_index('Skills')['Group'].to_dict()

Jobs['Skills'] = Jobs['Job_Description'].apply(lambda x: list(set([skills_dict[skill] for skill in skills_dict.keys() if skill in x])))

# %%
skills_freq = Jobs['Skills'].explode().value_counts()

skills_percent = skills_freq / len(Jobs) * 100

top_skills = skills_percent.sort_values(ascending=False)

skills_df_freq = pd.DataFrame({'Percentage': top_skills, 'Count': skills_freq[top_skills.index]})

skills_df_freq.style.format({'Percentage': '{:.2f}%'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_8056c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8056c_level0_col0" class="col_heading level0 col0" >Percentage</th>
#       <th id="T_8056c_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8056c_level0_row0" class="row_heading level0 row0" >Bachelor</th>
#       <td id="T_8056c_row0_col0" class="data row0 col0" >65.30%</td>
#       <td id="T_8056c_row0_col1" class="data row0 col1" >95592</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row1" class="row_heading level0 row1" >Office</th>
#       <td id="T_8056c_row1_col0" class="data row1 col0" >33.64%</td>
#       <td id="T_8056c_row1_col1" class="data row1 col1" >49247</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row2" class="row_heading level0 row2" >Excel</th>
#       <td id="T_8056c_row2_col0" class="data row2 col0" >28.32%</td>
#       <td id="T_8056c_row2_col1" class="data row2 col1" >41455</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row3" class="row_heading level0 row3" >SQL</th>
#       <td id="T_8056c_row3_col0" class="data row3 col0" >28.19%</td>
#       <td id="T_8056c_row3_col1" class="data row3 col1" >41269</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row4" class="row_heading level0 row4" >Python</th>
#       <td id="T_8056c_row4_col0" class="data row4 col0" >19.00%</td>
#       <td id="T_8056c_row4_col1" class="data row4 col1" >27813</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row5" class="row_heading level0 row5" >Master</th>
#       <td id="T_8056c_row5_col0" class="data row5 col0" >18.48%</td>
#       <td id="T_8056c_row5_col1" class="data row5 col1" >27050</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row6" class="row_heading level0 row6" >Access</th>
#       <td id="T_8056c_row6_col0" class="data row6 col0" >16.52%</td>
#       <td id="T_8056c_row6_col1" class="data row6 col1" >24184</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row7" class="row_heading level0 row7" >PowerPoint</th>
#       <td id="T_8056c_row7_col0" class="data row7 col0" >12.75%</td>
#       <td id="T_8056c_row7_col1" class="data row7 col1" >18663</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row8" class="row_heading level0 row8" >Tableau</th>
#       <td id="T_8056c_row8_col0" class="data row8 col0" >12.67%</td>
#       <td id="T_8056c_row8_col1" class="data row8 col1" >18546</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row9" class="row_heading level0 row9" >Power BI</th>
#       <td id="T_8056c_row9_col0" class="data row9 col0" >12.49%</td>
#       <td id="T_8056c_row9_col1" class="data row9 col1" >18279</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row10" class="row_heading level0 row10" >CPA</th>
#       <td id="T_8056c_row10_col0" class="data row10 col0" >12.09%</td>
#       <td id="T_8056c_row10_col1" class="data row10 col1" >17692</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row11" class="row_heading level0 row11" >Word</th>
#       <td id="T_8056c_row11_col0" class="data row11 col0" >9.81%</td>
#       <td id="T_8056c_row11_col1" class="data row11 col1" >14367</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row12" class="row_heading level0 row12" >Agile</th>
#       <td id="T_8056c_row12_col0" class="data row12 col0" >8.00%</td>
#       <td id="T_8056c_row12_col1" class="data row12 col1" >11706</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row13" class="row_heading level0 row13" >AWS</th>
#       <td id="T_8056c_row13_col0" class="data row13 col0" >7.72%</td>
#       <td id="T_8056c_row13_col1" class="data row13 col1" >11307</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row14" class="row_heading level0 row14" >ERP</th>
#       <td id="T_8056c_row14_col0" class="data row14 col0" >7.65%</td>
#       <td id="T_8056c_row14_col1" class="data row14 col1" >11201</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row15" class="row_heading level0 row15" >R</th>
#       <td id="T_8056c_row15_col0" class="data row15 col0" >7.16%</td>
#       <td id="T_8056c_row15_col1" class="data row15 col1" >10480</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row16" class="row_heading level0 row16" >SAP</th>
#       <td id="T_8056c_row16_col0" class="data row16 col0" >6.90%</td>
#       <td id="T_8056c_row16_col1" class="data row16 col1" >10108</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row17" class="row_heading level0 row17" >Azure</th>
#       <td id="T_8056c_row17_col0" class="data row17 col0" >6.41%</td>
#       <td id="T_8056c_row17_col1" class="data row17 col1" >9379</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row18" class="row_heading level0 row18" >Oracle</th>
#       <td id="T_8056c_row18_col0" class="data row18 col0" >6.15%</td>
#       <td id="T_8056c_row18_col1" class="data row18 col1" >8997</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row19" class="row_heading level0 row19" >Artificial Intelligence</th>
#       <td id="T_8056c_row19_col0" class="data row19 col0" >6.03%</td>
#       <td id="T_8056c_row19_col1" class="data row19 col1" >8831</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row20" class="row_heading level0 row20" >MBA</th>
#       <td id="T_8056c_row20_col0" class="data row20 col0" >5.78%</td>
#       <td id="T_8056c_row20_col1" class="data row20 col1" >8458</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row21" class="row_heading level0 row21" >Spark</th>
#       <td id="T_8056c_row21_col0" class="data row21 col0" >4.95%</td>
#       <td id="T_8056c_row21_col1" class="data row21 col1" >7243</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row22" class="row_heading level0 row22" >English</th>
#       <td id="T_8056c_row22_col0" class="data row22 col0" >4.91%</td>
#       <td id="T_8056c_row22_col1" class="data row22 col1" >7182</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row23" class="row_heading level0 row23" >Machine Learning</th>
#       <td id="T_8056c_row23_col0" class="data row23 col0" >4.86%</td>
#       <td id="T_8056c_row23_col1" class="data row23 col1" >7111</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row24" class="row_heading level0 row24" >Java</th>
#       <td id="T_8056c_row24_col0" class="data row24 col0" >3.80%</td>
#       <td id="T_8056c_row24_col1" class="data row24 col1" >5570</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row25" class="row_heading level0 row25" >Snowflake</th>
#       <td id="T_8056c_row25_col0" class="data row25 col0" >3.41%</td>
#       <td id="T_8056c_row25_col1" class="data row25 col1" >4986</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row26" class="row_heading level0 row26" >PhD</th>
#       <td id="T_8056c_row26_col0" class="data row26 col0" >3.14%</td>
#       <td id="T_8056c_row26_col1" class="data row26 col1" >4601</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row27" class="row_heading level0 row27" >Salesforce</th>
#       <td id="T_8056c_row27_col0" class="data row27 col0" >3.04%</td>
#       <td id="T_8056c_row27_col1" class="data row27 col1" >4455</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row28" class="row_heading level0 row28" >Hadoop</th>
#       <td id="T_8056c_row28_col0" class="data row28 col0" >2.70%</td>
#       <td id="T_8056c_row28_col1" class="data row28 col1" >3959</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row29" class="row_heading level0 row29" >Tensor Flow</th>
#       <td id="T_8056c_row29_col0" class="data row29 col0" >2.30%</td>
#       <td id="T_8056c_row29_col1" class="data row29 col1" >3361</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row30" class="row_heading level0 row30" >Databricks</th>
#       <td id="T_8056c_row30_col0" class="data row30 col0" >2.20%</td>
#       <td id="T_8056c_row30_col1" class="data row30 col1" >3218</td>
#     </tr>
#     <tr>
#       <th id="T_8056c_level0_row31" class="row_heading level0 row31" >C++</th>
#       <td id="T_8056c_row31_col0" class="data row31 col0" >2.18%</td>
#       <td id="T_8056c_row31_col1" class="data row31 col1" >3192</td>
#     </tr>
#     <tr>
#       <th id="T_

# %% [markdown]
# Perfect!

# %% [markdown]
# # Generating the csv file
#
# The last part is generate the final file. We are going to generate a csv format file. But first of all, we need to reorganize the columns:

# %%
Jobs_csv = Jobs[['ID','Job','Jobs_Group','Profile','Remote','Company','Location','City','State','Salary','Frecuency_Salary','Low_Salary','High_Salary','Mean_Salary','Skills']]

# %%
Jobs_csv
# Out:
#                        ID                                                Job  \
# 0     sj_cd2707991b8bc653            Market Development Representative 16702
# 1     sj_aa0f5247ff3deca7                   Vice President, Quality Services
# 2    job_bd203b586ac89e05                                   Business Analyst
# 3     sj_8cb506d1ac43bc43  Corporate Strategy and Business Development Ma...
# 4     sj_bdfad91ca716ac0f                Data Analyst, Business Intelligence
# ..                    ...                                                ...
# 969  job_a88f74a87f1c6e48         Property Controller- Graduate East Lansing
# 972  job_6fe37642cf95726f                               Assistant Controller
# 980  job_094beaf0996c95fe                                   Plant Controller
# 981  job_f3027b081096ff4c                                         Controller
# 987  job_f6fc5130f7639a6e                                   Plant Controller
#
#            Jobs_Group Profile  Remote                           Company  \
# 0        Data Analyst    None  Remote          Corps Team Services, LLC
# 1                 CFO    None  Hybrid           Family Support Services
# 2    Business Analyst    None  Remote                       Leonardo247
# 3    Business Analyst    Lead  Remote               United Therapeutics
# 4        Data Analyst    None    None                     Land O' Frost
# ..                ...     ...     ...                               ...
# 969        Controller    None    None                 Schulte Companies
# 972        Controller    None    None  Home State Insurance Group, Inc.
# 980        Controller    None    None               Dometic Corporation
# 981        Controller    None  Remote             The Talance Group, LP
# 987        Controller    None    None                  Johnson Controls
#
#                                Location                    City State  \
# 0                               Arizona                     NaN    AZ
# 1                 Tampa, FL+2 locations                   Tampa    FL
# 2                                Remote                     NaN   NaN
# 3            Research Triangle Park, NC  Research Triangle Park    NC
# 4    Madisonville, KY 42431+2 locations            Madisonville    KY
# ..                                  ...                     ...   ...
# 969  East Lansing, MI 48823+1 ubicación            East Lansing    MI
# 972          Waco, TX 76710+1 ubicación                    Waco    TX
# 980                  Cerritos, CA 90703                Cerritos    CA
# 981   Houston, TX 77002 (Downtown area)                 Houston    TX
# 987         Marinette, WI+5 ubicaciones               Marinette    WI
#
#                          Salary Frecuency_Salary  Low_Salary  High_Salary  \
# 0      $26.17 - $28.17 por hora             hora     48152.8      51832.8
# 1                           NaN              NaN         NaN          NaN
# 2                           NaN              NaN         NaN          NaN
# 3                           NaN              NaN         NaN          NaN
# 4    $89,100 - $108,900 por año              año     89100.0     108900.0
# ..                          ...              ...         ...          ...
# 969                         NaN              NaN         NaN          NaN
# 972                         NaN              NaN         NaN          NaN
# 980                         NaN              NaN         NaN          NaN
# 981                         NaN              NaN         NaN          NaN
# 987                         NaN              NaN         NaN          NaN
#
#      Mean_Salary                                             Skills
# 0        49992.8                                                 []
# 1            NaN                              [PHP, .NET, Bachelor]
# 2            NaN                                                 []
# 3            NaN                              [PhD, Office, Master]
# 4        99000.0         [C#, Bachelor, VBA, HTML, SSRS, .NET, SQL]
# ..           ...                                                ...
# 969          NaN                                 [Office, Bachelor]
# 972          NaN                    [Word, Excel, Office, Bachelor]
# 980          NaN  [Master, Dynamics 365, Access, Excel, Qlik, Of...
# 981          NaN                                              [CPA]
# 987          NaN  [MBA, Word, SAP, Excel, ERP, PowerPoint, Bache...
#
# [146392 rows x 15 columns]

# %%
Jobs_csv.to_csv('jobs.csv', index=False, encoding="utf-16")
Jobs_csv.to_excel('jobs.xlsx', index=False)

# %% [markdown]
# ### THANK YOU!!
