# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Files Loading

# %% [markdown]
# We load all the files in the folder "data":

# %%
folder = 'data_jobs'
files = os.listdir(folder)

dfs = []

headers = ['Job','URL','Company','Location','Salary','Posted','ID','Job_Description']

for file in files:
    path = os.path.join(folder, file)
    
    df = pd.read_excel(path, names=headers)
    
    dfs.append(df)

Jobs = pd.concat(dfs)

# %% [markdown]
# # Data Cleaning
#
# First of all, we need to delete all the duplicated values we could have. The best column to do so is the "ID" column:

# %%
Jobs = Jobs.drop_duplicates(subset='ID')

# %% [markdown]
# Let's see how it looks like the df:

# %%
Jobs.describe()
# Out:
#                       Job                                                URL  \
# count               44594                                              44594
# unique              22136                                              44594
# top     Financial Analyst  https://www.indeed.com/rc/clk?jk=dd21611605e12...
# freq                 1358                                                  1
#
#                           Company Location                       Salary  \
# count                       44563    44594                        17979
# unique                      17760    14781                         8089
# top     JPMorgan Chase Bank, N.A.   Remote  $100,000 - $120,000 por año
# freq                          278     2479                          115
#
#            Posted                    ID  \
# count       38903                 44594
# unique         58                 44594
# top     PostedHoy  job_dd21611605e12f1c
# freq        13838                     1
#
#                                           Job_Description
# count                                               44594
# unique                                              44034
# top     Ir directamente al contenido principal_x000D_\...
# freq                                                   14

# %%
Jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44594 entries, 0 to 987
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job              44594 non-null  object
#  1   URL              44594 non-null  object
#  2   Company          44563 non-null  object
#  3   Location         44594 non-null  object
#  4   Salary           17979 non-null  object
#  5   Posted           38903 non-null  object
#  6   ID               44594 non-null  object
#  7   Job_Description  44594 non-null  object
# dtypes: object(8)
# memory usage: 3.1+ MB

# %% [markdown]
# We see we have almost all the columns with non-null values, except Salary and Posted. The column Posted is not critic, since it's a column that shows when the job posting was published in terms of the extraction date. It doesn't seem very useful, so we can't drop it.
#
# With regards to the Salary column, we see we have aprox 30-35% of non-null values.
# #### Could we estimate the Salary null values?
# Let's see it later!

# %%
Jobs.drop(columns=['Posted'])
# Out:
#                                              Job  \
# 0     Enterprise Business Intelligence Analyst I
# 1          Business Analyst, Commercial Strategy
# 2                             Business Analyst I
# 3    Sr. Analyst, Business Optimization (Remote)
# 4      Business Risk Analyst I - Commercial Risk
# ..                                           ...
# 969   Property Controller- Graduate East Lansing
# 972                         Assistant Controller
# 980                             Plant Controller
# 981                                   Controller
# 987                             Plant Controller
#
#                                                    URL  \
# 0    https://www.indeed.com/rc/clk?jk=dd21611605e12...
# 1    https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...
# 2    https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...
# 3    https://www.indeed.com/rc/clk?jk=f78f07684adbc...
# 4    https://www.indeed.com/rc/clk?jk=72945a28e3458...
# ..                                                 ...
# 969  https://www.indeed.com/rc/clk?jk=a88f74a87f1c6...
# 972  https://www.indeed.com/rc/clk?jk=6fe37642cf957...
# 980  https://www.indeed.com/rc/clk?jk=094beaf0996c9...
# 981  https://www.indeed.com/rc/clk?jk=f3027b081096f...
# 987  https://www.indeed.com/rc/clk?jk=f6fc5130f7639...
#
#                               Company                            Location  \
# 0                       BOK Financial                     Tulsa, OK 74101
# 1                         Live Nation                         Chicago, IL
# 2                                Amex                         Phoenix, AZ
# 3                             Staples                              Remote
# 4                            M&T Bank                         Buffalo, NY
# ..                                ...                                 ...
# 969                 Schulte Companies  East Lansing, MI 48823+1 ubicación
# 972  Home State Insurance Group, Inc.          Waco, TX 76710+1 ubicación
# 980               Dometic Corporation                  Cerritos, CA 90703
# 981             The Talance Group, LP   Houston, TX 77002 (Downtown area)
# 987                  Johnson Controls         Marinette, WI+5 ubicaciones
#
#                          Salary                    ID  \
# 0                           NaN  job_dd21611605e12f1c
# 1                           NaN  job_64d9fb0d5e3351ae
# 2    $55,000 - $105,000 por año  job_3f63ec9a3f8d6a9e
# 3     $57,300 - $86,400 por año  job_f78f07684adbc4c4
# 4                           NaN  job_72945a28e345817a
# ..                          ...                   ...
# 969                         NaN  job_a88f74a87f1c6e48
# 972                         NaN  job_6fe37642cf95726f
# 980                         NaN  job_094beaf0996c95fe
# 981                         NaN  job_f3027b081096ff4c
# 987                         NaN  job_f6fc5130f7639a6e
#
#                                        Job_Description
# 0    Ir directamente al contenido principal_x000D_\...
# 1    Ir directamente al contenido principal_x000D_\...
# 2    Ir directamente al contenido principal_x000D_\...
# 3    Ir directamente al contenido principal_x000D_\...
# 4    Ir directamente al contenido principal_x000D_\...
# ..                                                 ...
# 969  Ir directamente al contenido principal_x000D_\...
# 972  Ir directamente al contenido principal_x000D_\...
# 980  Ir directamente al contenido principal_x000D_\...
# 981  Ir directamente al contenido principal_x000D_\...
# 987  Ir directamente al contenido principal_x000D_\...
#
# [44594 rows x 7 columns]

# %% [markdown]
# We saw all the Dtypes are object. However, the Salary column would be interesting to be a numeric column.

# %% [markdown]
# ## Salary

# %% [markdown]
# Let's see how it looks like:

# %%
Jobs['Salary'].head(50).values.tolist()
# Out:
# [nan,
#  nan,
#  '$55,000 - $105,000 por año',
#  '$57,300 - $86,400 por año',
#  nan,
#  '$67,000 - $100,000 por año',
#  nan,
#  nan,
#  nan,
#  '$60,000 - $132,000 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  '$70 por hora',
#  '$70,785 - $107,640 por año',
#  '$65,490 - $88,660 por año',
#  nan,
#  nan,
#  '$65,000 - $105,000 por año',
#  nan,
#  nan,
#  '$154,523 - $169,854 por año',
#  '$66,300 - $137,700 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '$68,395 - $97,933 por año',
#  '$54,000 - $134,000 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '$63,118 - $87,346 por año',
#  nan,
#  nan,
#  nan]

# %% [markdown]
# It looks horrible! We have single values, we have ranges, we have salary per year (año), month (mes), week (semana), day (día), and hourly (hora). Moreover we have the $ symbol in all the values, and in some cases we have the words Desde (From), and Hasta (Up to). Let's clean it!
#
# First of all, the frecuency pay could be interesting in order to standardize the salaries. Let's split it into a new column:

# %%
Jobs['Frecuency_Salary'] = Jobs['Salary'].str.split(' por ').str.get(1)

# %%
Jobs['Frecuency_Salary'].unique()
# Out:
# array([nan, 'año', 'hora', 'mes', 'semana', 'día'], dtype=object)

# %%
Jobs.head()
# Out:
#                                            Job  \
# 0   Enterprise Business Intelligence Analyst I
# 1        Business Analyst, Commercial Strategy
# 2                           Business Analyst I
# 3  Sr. Analyst, Business Optimization (Remote)
# 4    Business Risk Analyst I - Commercial Risk
#
#                                                  URL        Company  \
# 0  https://www.indeed.com/rc/clk?jk=dd21611605e12...  BOK Financial
# 1  https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...    Live Nation
# 2  https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...           Amex
# 3  https://www.indeed.com/rc/clk?jk=f78f07684adbc...        Staples
# 4  https://www.indeed.com/rc/clk?jk=72945a28e3458...       M&T Bank
#
#           Location                      Salary  \
# 0  Tulsa, OK 74101                         NaN
# 1      Chicago, IL                         NaN
# 2      Phoenix, AZ  $55,000 - $105,000 por año
# 3           Remote   $57,300 - $86,400 por año
# 4      Buffalo, NY                         NaN
#
#                                 Posted                    ID  \
# 0          PostedPublicado hace 2 días  job_dd21611605e12f1c
# 1  PostedPublicado hace más de 30 días  job_64d9fb0d5e3351ae
# 2  PostedPublicado hace más de 30 días  job_3f63ec9a3f8d6a9e
# 3          PostedPublicado hace 3 días  job_f78f07684adbc4c4
# 4          PostedPublicado hace 6 días  job_72945a28e345817a
#
#                                      Job_Description Frecuency_Salary
# 0  Ir directamente al contenido principal_x000D_\...              NaN
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              año
# 3  Ir directamente al contenido principal_x000D_\...              año
# 4  Ir directamente al contenido principal_x000D_\...              NaN

# %% [markdown]
# Nice! Now let's delete the words "Desde " and "Hasta ":

# %%
Jobs['Salary'] = Jobs['Salary'].str.replace('Desde ','')
Jobs['Salary'] = Jobs['Salary'].str.replace('Hasta ','')

# %%
Jobs.head()
# Out:
#                                            Job  \
# 0   Enterprise Business Intelligence Analyst I
# 1        Business Analyst, Commercial Strategy
# 2                           Business Analyst I
# 3  Sr. Analyst, Business Optimization (Remote)
# 4    Business Risk Analyst I - Commercial Risk
#
#                                                  URL        Company  \
# 0  https://www.indeed.com/rc/clk?jk=dd21611605e12...  BOK Financial
# 1  https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...    Live Nation
# 2  https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...           Amex
# 3  https://www.indeed.com/rc/clk?jk=f78f07684adbc...        Staples
# 4  https://www.indeed.com/rc/clk?jk=72945a28e3458...       M&T Bank
#
#           Location                      Salary  \
# 0  Tulsa, OK 74101                         NaN
# 1      Chicago, IL                         NaN
# 2      Phoenix, AZ  $55,000 - $105,000 por año
# 3           Remote   $57,300 - $86,400 por año
# 4      Buffalo, NY                         NaN
#
#                                 Posted                    ID  \
# 0          PostedPublicado hace 2 días  job_dd21611605e12f1c
# 1  PostedPublicado hace más de 30 días  job_64d9fb0d5e3351ae
# 2  PostedPublicado hace más de 30 días  job_3f63ec9a3f8d6a9e
# 3          PostedPublicado hace 3 días  job_f78f07684adbc4c4
# 4          PostedPublicado hace 6 días  job_72945a28e345817a
#
#                                      Job_Description Frecuency_Salary
# 0  Ir directamente al contenido principal_x000D_\...              NaN
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              año
# 3  Ir directamente al contenido principal_x000D_\...              año
# 4  Ir directamente al contenido principal_x000D_\...              NaN

# %% [markdown]
# Let's work on the range values. An interesting approach would be to have two new columns, for the low part of the range, and another for the high part of the range:

# %%
salary_split = Jobs['Salary'].str.split('-', expand=True)
Jobs['Low_Salary'] = salary_split[0].str.strip()
Jobs['High_Salary'] = salary_split[1].str.strip()

# %% [markdown]
# With these split, all the non-range values, will have value only in the Low_Salary column. In this cases, let's set the same values for all low and high salary columns:

# %%
Jobs['High_Salary'] = Jobs['High_Salary'].fillna(Jobs['Low_Salary'])

# %%
Jobs.head()
# Out:
#                                            Job  \
# 0   Enterprise Business Intelligence Analyst I
# 1        Business Analyst, Commercial Strategy
# 2                           Business Analyst I
# 3  Sr. Analyst, Business Optimization (Remote)
# 4    Business Risk Analyst I - Commercial Risk
#
#                                                  URL        Company  \
# 0  https://www.indeed.com/rc/clk?jk=dd21611605e12...  BOK Financial
# 1  https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...    Live Nation
# 2  https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...           Amex
# 3  https://www.indeed.com/rc/clk?jk=f78f07684adbc...        Staples
# 4  https://www.indeed.com/rc/clk?jk=72945a28e3458...       M&T Bank
#
#           Location                      Salary  \
# 0  Tulsa, OK 74101                         NaN
# 1      Chicago, IL                         NaN
# 2      Phoenix, AZ  $55,000 - $105,000 por año
# 3           Remote   $57,300 - $86,400 por año
# 4      Buffalo, NY                         NaN
#
#                                 Posted                    ID  \
# 0          PostedPublicado hace 2 días  job_dd21611605e12f1c
# 1  PostedPublicado hace más de 30 días  job_64d9fb0d5e3351ae
# 2  PostedPublicado hace más de 30 días  job_3f63ec9a3f8d6a9e
# 3          PostedPublicado hace 3 días  job_f78f07684adbc4c4
# 4          PostedPublicado hace 6 días  job_72945a28e345817a
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              NaN
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              año
# 3  Ir directamente al contenido principal_x000D_\...              año
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#   Low_Salary       High_Salary
# 0        NaN               NaN
# 1        NaN               NaN
# 2    $55,000  $105,000 por año
# 3    $57,300   $86,400 por año
# 4        NaN               NaN

# %% [markdown]
# We see how it looks better, but we need to clean the non numeric values for both columns. So let's replace all the non numeric strings:

# %%
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace('[\$,]', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace('[\$,]', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por hora', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por hora', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por día', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por día', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por año', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por año', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por mes', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por mes', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por semana', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por semana', '', regex=True)

# %%
Jobs.head()
# Out:
#                                            Job  \
# 0   Enterprise Business Intelligence Analyst I
# 1        Business Analyst, Commercial Strategy
# 2                           Business Analyst I
# 3  Sr. Analyst, Business Optimization (Remote)
# 4    Business Risk Analyst I - Commercial Risk
#
#                                                  URL        Company  \
# 0  https://www.indeed.com/rc/clk?jk=dd21611605e12...  BOK Financial
# 1  https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...    Live Nation
# 2  https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...           Amex
# 3  https://www.indeed.com/rc/clk?jk=f78f07684adbc...        Staples
# 4  https://www.indeed.com/rc/clk?jk=72945a28e3458...       M&T Bank
#
#           Location                      Salary  \
# 0  Tulsa, OK 74101                         NaN
# 1      Chicago, IL                         NaN
# 2      Phoenix, AZ  $55,000 - $105,000 por año
# 3           Remote   $57,300 - $86,400 por año
# 4      Buffalo, NY                         NaN
#
#                                 Posted                    ID  \
# 0          PostedPublicado hace 2 días  job_dd21611605e12f1c
# 1  PostedPublicado hace más de 30 días  job_64d9fb0d5e3351ae
# 2  PostedPublicado hace más de 30 días  job_3f63ec9a3f8d6a9e
# 3          PostedPublicado hace 3 días  job_f78f07684adbc4c4
# 4          PostedPublicado hace 6 días  job_72945a28e345817a
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              NaN
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              año
# 3  Ir directamente al contenido principal_x000D_\...              año
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#   Low_Salary High_Salary
# 0        NaN         NaN
# 1        NaN         NaN
# 2      55000      105000
# 3      57300       86400
# 4        NaN         NaN

# %% [markdown]
# Good! Now we need to standardize the Salaries, into a unique frecuency. The most common is to show the salary yearly. So let's transform all the non-yearly salaries into a yearly:

# %%
Jobs['Low_Salary'] = Jobs['Low_Salary'].astype(float)
Jobs['High_Salary'] = Jobs['High_Salary'].astype(float)

# %%
def transform_salary(row):
    if row['Frecuency_Salary'] == 'año':
        factor = 1
    elif row['Frecuency_Salary'] == 'mes':
        factor = 12
    elif row['Frecuency_Salary'] == 'semana':
        factor = 49
    elif row['Frecuency_Salary'] == 'día':
        factor = 230
    elif row['Frecuency_Salary'] == 'hora':
        factor = 1840
    else:
        factor = 1
    row['Low_Salary'] *= factor
    row['High_Salary'] *= factor
    return row

Jobs = Jobs.apply(transform_salary, axis=1)

# %%
Jobs.head()
# Out:
#                                            Job  \
# 0   Enterprise Business Intelligence Analyst I
# 1        Business Analyst, Commercial Strategy
# 2                           Business Analyst I
# 3  Sr. Analyst, Business Optimization (Remote)
# 4    Business Risk Analyst I - Commercial Risk
#
#                                                  URL        Company  \
# 0  https://www.indeed.com/rc/clk?jk=dd21611605e12...  BOK Financial
# 1  https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...    Live Nation
# 2  https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...           Amex
# 3  https://www.indeed.com/rc/clk?jk=f78f07684adbc...        Staples
# 4  https://www.indeed.com/rc/clk?jk=72945a28e3458...       M&T Bank
#
#           Location                      Salary  \
# 0  Tulsa, OK 74101                         NaN
# 1      Chicago, IL                         NaN
# 2      Phoenix, AZ  $55,000 - $105,000 por año
# 3           Remote   $57,300 - $86,400 por año
# 4      Buffalo, NY                         NaN
#
#                                 Posted                    ID  \
# 0          PostedPublicado hace 2 días  job_dd21611605e12f1c
# 1  PostedPublicado hace más de 30 días  job_64d9fb0d5e3351ae
# 2  PostedPublicado hace más de 30 días  job_3f63ec9a3f8d6a9e
# 3          PostedPublicado hace 3 días  job_f78f07684adbc4c4
# 4          PostedPublicado hace 6 días  job_72945a28e345817a
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              NaN
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              año
# 3  Ir directamente al contenido principal_x000D_\...              año
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#    Low_Salary  High_Salary
# 0         NaN          NaN
# 1         NaN          NaN
# 2     55000.0     105000.0
# 3     57300.0      86400.0
# 4         NaN          NaN

# %% [markdown]
# Nice! The last step here, is to create a unique column with salaries. The purpose of this is to compare and analyze, since some of the salaries are ranges and some others are not. The best approach for this is to have a mean salary column:

# %%
Jobs['Mean_Salary'] = (Jobs['Low_Salary'] + Jobs['High_Salary']) / 2

# %%
Jobs.head()
# Out:
#                                            Job  \
# 0   Enterprise Business Intelligence Analyst I
# 1        Business Analyst, Commercial Strategy
# 2                           Business Analyst I
# 3  Sr. Analyst, Business Optimization (Remote)
# 4    Business Risk Analyst I - Commercial Risk
#
#                                                  URL        Company  \
# 0  https://www.indeed.com/rc/clk?jk=dd21611605e12...  BOK Financial
# 1  https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...    Live Nation
# 2  https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...           Amex
# 3  https://www.indeed.com/rc/clk?jk=f78f07684adbc...        Staples
# 4  https://www.indeed.com/rc/clk?jk=72945a28e3458...       M&T Bank
#
#           Location                      Salary  \
# 0  Tulsa, OK 74101                         NaN
# 1      Chicago, IL                         NaN
# 2      Phoenix, AZ  $55,000 - $105,000 por año
# 3           Remote   $57,300 - $86,400 por año
# 4      Buffalo, NY                         NaN
#
#                                 Posted                    ID  \
# 0          PostedPublicado hace 2 días  job_dd21611605e12f1c
# 1  PostedPublicado hace más de 30 días  job_64d9fb0d5e3351ae
# 2  PostedPublicado hace más de 30 días  job_3f63ec9a3f8d6a9e
# 3          PostedPublicado hace 3 días  job_f78f07684adbc4c4
# 4          PostedPublicado hace 6 días  job_72945a28e345817a
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              NaN
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              año
# 3  Ir directamente al contenido principal_x000D_\...              año
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#    Low_Salary  High_Salary  Mean_Salary
# 0         NaN          NaN          NaN
# 1         NaN          NaN          NaN
# 2     55000.0     105000.0      80000.0
# 3     57300.0      86400.0      71850.0
# 4         NaN          NaN          NaN

# %% [markdown]
# PERFECT!

# %% [markdown]
# ## Jobs Group
#
# Since the Job names are quite heterogeneus, it's mandatory to group them in a few job groups. Let's do it with the dictionary categories.xlsx:

# %%
category_df = pd.read_excel('master_data\categories.xlsx')

category_df.head()
# Out:
#             keyword        category
# 0     data engineer   Data Engineer
# 1    data scientist  Data Scientist
# 2      data science  Data Scientist
# 3               ds   Data Scientist
# 4  machine learning  ML/AI Engineer

# %%
categories = category_df.set_index('keyword')['category'].to_dict()

def assign_category(job):
    job = job.lower()
    for keyword, category in categories.items():
        if keyword in job:
            return category
    return 'Others'

Jobs['Jobs_Group'] = Jobs['Job'].apply(assign_category)

# %%
category_counts = Jobs['Jobs_Group'].value_counts()

print(category_counts)
# Out:
# Financial Analyst            7823
# Business Analyst             6935
# Data Analyst                 5629
# Data Engineer                4403
# Controller                   3856
# Data Scientist               3360
# Business Intelligence        2877
# CFO                          2263
# Finance                      2077
# Analyst                      1870
# Operations Analyst           1242
# ML/AI Engineer                955
# Others                        918
# Statistician/Mathemathics     386
# Name: Jobs_Group, dtype: int64

# %% [markdown]
# Nice!

# %% [markdown]
# ## Location

# %% [markdown]
# The next step would be to clean the Location column. Would be nice to have a City and State column. The best way to split it, is to split it two columns by comma, getting all the string before, and the two letters after comma. The first column will be the city, and the second one the state. Let's work on it!

# %%
Jobs[['City', 'State']] = Jobs['Location'].str.extract(r'^(.+),\s([A-Z]{2})', expand=True)

# %%
Jobs.head()
# Out:
#                                            Job  \
# 0   Enterprise Business Intelligence Analyst I
# 1        Business Analyst, Commercial Strategy
# 2                           Business Analyst I
# 3  Sr. Analyst, Business Optimization (Remote)
# 4    Business Risk Analyst I - Commercial Risk
#
#                                                  URL        Company  \
# 0  https://www.indeed.com/rc/clk?jk=dd21611605e12...  BOK Financial
# 1  https://www.indeed.com/rc/clk?jk=64d9fb0d5e335...    Live Nation
# 2  https://www.indeed.com/rc/clk?jk=3f63ec9a3f8d6...           Amex
# 3  https://www.indeed.com/rc/clk?jk=f78f07684adbc...        Staples
# 4  https://www.indeed.com/rc/clk?jk=72945a28e3458...       M&T Bank
#
#           Location                      Salary  \
# 0  Tulsa, OK 74101                         NaN
# 1      Chicago, IL                         NaN
# 2      Phoenix, AZ  $55,000 - $105,000 por año
# 3           Remote   $57,300 - $86,400 por año
# 4      Buffalo, NY                         NaN
#
#                                 Posted                    ID  \
# 0          PostedPublicado hace 2 días  job_dd21611605e12f1c
# 1  PostedPublicado hace más de 30 días  job_64d9fb0d5e3351ae
# 2  PostedPublicado hace más de 30 días  job_3f63ec9a3f8d6a9e
# 3          PostedPublicado hace 3 días  job_f78f07684adbc4c4
# 4          PostedPublicado hace 6 días  job_72945a28e345817a
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              NaN
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              año
# 3  Ir directamente al contenido principal_x000D_\...              año
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#    Low_Salary  High_Salary  Mean_Salary             Jobs_Group     City State
# 0         NaN          NaN          NaN  Business Intelligence    Tulsa    OK
# 1         NaN          NaN          NaN       Business Analyst  Chicago    IL
# 2     55000.0     105000.0      80000.0       Business Analyst  Phoenix    AZ
# 3     57300.0      86400.0      71850.0       Business Analyst      NaN   NaN
# 4         NaN          NaN          NaN       Business Analyst  Buffalo    NY

# %%
Jobs['City'].values
# Out:
# array(['Tulsa', 'Chicago', 'Phoenix', ..., 'Cerritos', 'Houston',
#        'Marinette'], dtype=object)

# %%
Jobs['State'].values
# Out:
# array(['OK', 'IL', 'AZ', ..., 'CA', 'TX', 'WI'], dtype=object)

# %% [markdown]
# Nice! Now a minor problem, is that there is some Locations, that are directy the state (e.g. California). In this cases, let's create a function, using the dictionary states.xlsx:

# %%
states_df = pd.read_excel('master_data\states.xlsx')

states_df.head()
# Out:
#         State Code
# 0     Alabama   AL
# 1      Alaska   AK
# 2     Arizona   AZ
# 3    Arkansas   AR
# 4  California   CA

# %%
states_dict = states_df.set_index('State')['Code'].to_dict()

def assign_state(row):
    if pd.isnull(row['State']):
        for state, code in states_dict.items():
            if state.lower() in row['Location'].lower():
                return code
    return row['State']

Jobs['State'] = Jobs.apply(assign_state, axis=1)

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Remote
#
# An interesting column would be if a job is remote or hybrid or none of these. In order to do so, we can use a dictionary with keywords:

# %%
remote_df = pd.read_excel('master_data/remote.xlsx')

remote_df.head()
# Out:
#             Value Category
# 0          Remote   Remote
# 1          remote   Remote
# 2          Hybrid   Hybrid
# 3          hybrid   Hybrid
# 4  Work From Home   Remote

# %%
remote_dict = remote_df.set_index('Value')['Category'].to_dict()

def assign_remote(row):
    for col in ['Job', 'Location', 'Job_Description']:
        for value, category in remote_dict.items():
            if value.lower() in row[col].lower():
                return category
    return None

Jobs['Remote'] = Jobs.apply(assign_remote, axis=1)

# %%
remote_counts = Jobs['Remote'].value_counts()

print(remote_counts)
# Out:
# Remote    13058
# Hybrid     4680
# Name: Remote, dtype: int64

# %% [markdown]
# Looks great!

# %% [markdown]
# ## Profile
#
# Another interesting column is the profile. In this column we will show if it's a Lead, Senior or a Junior position. As we did in the remote column, we will use a dictionary:

# %%
profile_df = pd.read_excel('master_data\profile.xlsx')

profile_df.head()
# Out:
#     Value Profile
# 0  junior  Junior
# 1  Junior  Junior
# 2      Jr  Junior
# 3     Jr.  Junior
# 4  senior  Senior

# %%
profile_dict = profile_df.set_index('Value')['Profile'].to_dict()

def assign_profile(row):
    for col in ['Job']:
        for value, profile in profile_dict.items():
            if value.lower() in row[col].lower():
                return profile
    return None

Jobs['Profile'] = Jobs.apply(assign_profile, axis=1)

# %%
profile_counts = Jobs['Profile'].value_counts()

print(profile_counts)
# Out:
# Senior    8749
# Lead      6746
# Junior     524
# Name: Profile, dtype: int64

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Skills
#
# Now, let's deep into the job descriptions. Would be nice to have a Skills column. We can have it using a dictionary skills.xlsx:

# %%
skills_df = pd.read_excel('master_data\skills.xlsx')

skills_df.head()
# Out:
#                 Skills            Group
# 0               Access           Access
# 1      Adobe Analytics  Adobe Analytics
# 2                  AWS              AWS
# 3  Amazon Web Services              AWS
# 4           Amazon Web              AWS

# %%
skills_dict = skills_df.set_index('Skills')['Group'].to_dict()

Jobs['Skills'] = Jobs['Job_Description'].apply(lambda x: list(set([skills_dict[skill] for skill in skills_dict.keys() if skill in x])))

# %%
skills_freq = Jobs['Skills'].explode().value_counts()

skills_percent = skills_freq / len(Jobs) * 100

top_skills = skills_percent.sort_values(ascending=False)

skills_df_freq = pd.DataFrame({'Percentage': top_skills, 'Count': skills_freq[top_skills.index]})

skills_df_freq.style.format({'Percentage': '{:.2f}%'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_fcd32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcd32_level0_col0" class="col_heading level0 col0" >Percentage</th>
#       <th id="T_fcd32_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcd32_level0_row0" class="row_heading level0 row0" >Bachelor</th>
#       <td id="T_fcd32_row0_col0" class="data row0 col0" >65.38%</td>
#       <td id="T_fcd32_row0_col1" class="data row0 col1" >29155</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row1" class="row_heading level0 row1" >Office</th>
#       <td id="T_fcd32_row1_col0" class="data row1 col0" >32.20%</td>
#       <td id="T_fcd32_row1_col1" class="data row1 col1" >14360</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row2" class="row_heading level0 row2" >SQL</th>
#       <td id="T_fcd32_row2_col0" class="data row2 col0" >30.09%</td>
#       <td id="T_fcd32_row2_col1" class="data row2 col1" >13417</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row3" class="row_heading level0 row3" >Excel</th>
#       <td id="T_fcd32_row3_col0" class="data row3 col0" >28.37%</td>
#       <td id="T_fcd32_row3_col1" class="data row3 col1" >12653</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row4" class="row_heading level0 row4" >Python</th>
#       <td id="T_fcd32_row4_col0" class="data row4 col0" >19.54%</td>
#       <td id="T_fcd32_row4_col1" class="data row4 col1" >8715</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row5" class="row_heading level0 row5" >Master</th>
#       <td id="T_fcd32_row5_col0" class="data row5 col0" >18.59%</td>
#       <td id="T_fcd32_row5_col1" class="data row5 col1" >8292</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row6" class="row_heading level0 row6" >Tableau</th>
#       <td id="T_fcd32_row6_col0" class="data row6 col0" >13.51%</td>
#       <td id="T_fcd32_row6_col1" class="data row6 col1" >6023</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row7" class="row_heading level0 row7" >Power BI</th>
#       <td id="T_fcd32_row7_col0" class="data row7 col0" >12.98%</td>
#       <td id="T_fcd32_row7_col1" class="data row7 col1" >5790</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row8" class="row_heading level0 row8" >PowerPoint</th>
#       <td id="T_fcd32_row8_col0" class="data row8 col0" >12.41%</td>
#       <td id="T_fcd32_row8_col1" class="data row8 col1" >5532</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row9" class="row_heading level0 row9" >Word</th>
#       <td id="T_fcd32_row9_col0" class="data row9 col0" >12.15%</td>
#       <td id="T_fcd32_row9_col1" class="data row9 col1" >5417</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row10" class="row_heading level0 row10" >CPA</th>
#       <td id="T_fcd32_row10_col0" class="data row10 col0" >10.89%</td>
#       <td id="T_fcd32_row10_col1" class="data row10 col1" >4856</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row11" class="row_heading level0 row11" >Agile</th>
#       <td id="T_fcd32_row11_col0" class="data row11 col0" >7.87%</td>
#       <td id="T_fcd32_row11_col1" class="data row11 col1" >3511</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row12" class="row_heading level0 row12" >Access</th>
#       <td id="T_fcd32_row12_col0" class="data row12 col0" >7.65%</td>
#       <td id="T_fcd32_row12_col1" class="data row12 col1" >3412</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row13" class="row_heading level0 row13" >AWS</th>
#       <td id="T_fcd32_row13_col0" class="data row13 col0" >7.53%</td>
#       <td id="T_fcd32_row13_col1" class="data row13 col1" >3358</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row14" class="row_heading level0 row14" >SAP</th>
#       <td id="T_fcd32_row14_col0" class="data row14 col0" >7.35%</td>
#       <td id="T_fcd32_row14_col1" class="data row14 col1" >3276</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row15" class="row_heading level0 row15" >ERP</th>
#       <td id="T_fcd32_row15_col0" class="data row15 col0" >7.31%</td>
#       <td id="T_fcd32_row15_col1" class="data row15 col1" >3261</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row16" class="row_heading level0 row16" >R</th>
#       <td id="T_fcd32_row16_col0" class="data row16 col0" >7.31%</td>
#       <td id="T_fcd32_row16_col1" class="data row16 col1" >3260</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row17" class="row_heading level0 row17" >Oracle</th>
#       <td id="T_fcd32_row17_col0" class="data row17 col0" >6.60%</td>
#       <td id="T_fcd32_row17_col1" class="data row17 col1" >2943</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row18" class="row_heading level0 row18" >Azure</th>
#       <td id="T_fcd32_row18_col0" class="data row18 col0" >6.26%</td>
#       <td id="T_fcd32_row18_col1" class="data row18 col1" >2792</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row19" class="row_heading level0 row19" >MBA</th>
#       <td id="T_fcd32_row19_col0" class="data row19 col0" >5.78%</td>
#       <td id="T_fcd32_row19_col1" class="data row19 col1" >2577</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row20" class="row_heading level0 row20" >Artificial Intelligence</th>
#       <td id="T_fcd32_row20_col0" class="data row20 col0" >5.31%</td>
#       <td id="T_fcd32_row20_col1" class="data row20 col1" >2367</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row21" class="row_heading level0 row21" >Spark</th>
#       <td id="T_fcd32_row21_col0" class="data row21 col0" >5.26%</td>
#       <td id="T_fcd32_row21_col1" class="data row21 col1" >2344</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row22" class="row_heading level0 row22" >English</th>
#       <td id="T_fcd32_row22_col0" class="data row22 col0" >4.98%</td>
#       <td id="T_fcd32_row22_col1" class="data row22 col1" >2220</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row23" class="row_heading level0 row23" >Machine Learning</th>
#       <td id="T_fcd32_row23_col0" class="data row23 col0" >4.77%</td>
#       <td id="T_fcd32_row23_col1" class="data row23 col1" >2129</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row24" class="row_heading level0 row24" >Java</th>
#       <td id="T_fcd32_row24_col0" class="data row24 col0" >3.90%</td>
#       <td id="T_fcd32_row24_col1" class="data row24 col1" >1737</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row25" class="row_heading level0 row25" >PhD</th>
#       <td id="T_fcd32_row25_col0" class="data row25 col0" >3.12%</td>
#       <td id="T_fcd32_row25_col1" class="data row25 col1" >1393</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row26" class="row_heading level0 row26" >Hadoop</th>
#       <td id="T_fcd32_row26_col0" class="data row26 col0" >3.03%</td>
#       <td id="T_fcd32_row26_col1" class="data row26 col1" >1352</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row27" class="row_heading level0 row27" >Salesforce</th>
#       <td id="T_fcd32_row27_col0" class="data row27 col0" >2.86%</td>
#       <td id="T_fcd32_row27_col1" class="data row27 col1" >1274</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row28" class="row_heading level0 row28" >HTML</th>
#       <td id="T_fcd32_row28_col0" class="data row28 col0" >2.23%</td>
#       <td id="T_fcd32_row28_col1" class="data row28 col1" >993</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row29" class="row_heading level0 row29" >Databricks</th>
#       <td id="T_fcd32_row29_col0" class="data row29 col0" >2.22%</td>
#       <td id="T_fcd32_row29_col1" class="data row29 col1" >988</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row30" class="row_heading level0 row30" >C++</th>
#       <td id="T_fcd32_row30_col0" class="data row30 col0" >2.17%</td>
#       <td id="T_fcd32_row30_col1" class="data row30 col1" >969</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row31" class="row_heading level0 row31" >SSIS</th>
#       <td id="T_fcd32_row31_col0" class="data row31 col0" >2.14%</td>
#       <td id="T_fcd32_row31_col1" class="data row31 col1" >954</td>
#     </tr>
#     <tr>
#       <th id="T_fcd32_level0_row32" class="ro

# %% [markdown]
# Perfect!

# %% [markdown]
# # Generating the csv file
#
# The last part is generate the final file. We are going to generate a csv format file. But first of all, we need to reorganize the columns:

# %%
Jobs_csv = Jobs[['ID','Job','Jobs_Group','Profile','Remote','Company','Location','City','State','Salary','Frecuency_Salary','Low_Salary','High_Salary','Mean_Salary','Skills']]

# %%
Jobs_csv
# Out:
#                        ID                                          Job  \
# 0    job_dd21611605e12f1c   Enterprise Business Intelligence Analyst I
# 1    job_64d9fb0d5e3351ae        Business Analyst, Commercial Strategy
# 2    job_3f63ec9a3f8d6a9e                           Business Analyst I
# 3    job_f78f07684adbc4c4  Sr. Analyst, Business Optimization (Remote)
# 4    job_72945a28e345817a    Business Risk Analyst I - Commercial Risk
# ..                    ...                                          ...
# 969  job_a88f74a87f1c6e48   Property Controller- Graduate East Lansing
# 972  job_6fe37642cf95726f                         Assistant Controller
# 980  job_094beaf0996c95fe                             Plant Controller
# 981  job_f3027b081096ff4c                                   Controller
# 987  job_f6fc5130f7639a6e                             Plant Controller
#
#                 Jobs_Group Profile  Remote                           Company  \
# 0    Business Intelligence    None    None                     BOK Financial
# 1         Business Analyst    None  Remote                       Live Nation
# 2         Business Analyst    None  Hybrid                              Amex
# 3         Business Analyst  Senior  Remote                           Staples
# 4         Business Analyst    None    None                          M&T Bank
# ..                     ...     ...     ...                               ...
# 969             Controller    None    None                 Schulte Companies
# 972             Controller    None    None  Home State Insurance Group, Inc.
# 980             Controller    None    None               Dometic Corporation
# 981             Controller    None  Remote             The Talance Group, LP
# 987             Controller    None    None                  Johnson Controls
#
#                                Location          City State  \
# 0                       Tulsa, OK 74101         Tulsa    OK
# 1                           Chicago, IL       Chicago    IL
# 2                           Phoenix, AZ       Phoenix    AZ
# 3                                Remote           NaN   NaN
# 4                           Buffalo, NY       Buffalo    NY
# ..                                  ...           ...   ...
# 969  East Lansing, MI 48823+1 ubicación  East Lansing    MI
# 972          Waco, TX 76710+1 ubicación          Waco    TX
# 980                  Cerritos, CA 90703      Cerritos    CA
# 981   Houston, TX 77002 (Downtown area)       Houston    TX
# 987         Marinette, WI+5 ubicaciones     Marinette    WI
#
#                          Salary Frecuency_Salary  Low_Salary  High_Salary  \
# 0                           NaN              NaN         NaN          NaN
# 1                           NaN              NaN         NaN          NaN
# 2    $55,000 - $105,000 por año              año     55000.0     105000.0
# 3     $57,300 - $86,400 por año              año     57300.0      86400.0
# 4                           NaN              NaN         NaN          NaN
# ..                          ...              ...         ...          ...
# 969                         NaN              NaN         NaN          NaN
# 972                         NaN              NaN         NaN          NaN
# 980                         NaN              NaN         NaN          NaN
# 981                         NaN              NaN         NaN          NaN
# 987                         NaN              NaN         NaN          NaN
#
#      Mean_Salary                                             Skills
# 0            NaN                       [Office, Power BI, Bachelor]
# 1            NaN             [PowerPoint, Tableau, Excel, Bachelor]
# 2        80000.0         [Master, Python, Excel, SQL, Tableau, VBA]
# 3        71850.0                                           [Office]
# 4            NaN                                         [Bachelor]
# ..           ...                                                ...
# 969          NaN                                 [Office, Bachelor]
# 972          NaN                    [Office, Word, Excel, Bachelor]
# 980          NaN  [Master, Dynamics 365, Excel, PowerPoint, Qlik...
# 981          NaN                                              [CPA]
# 987          NaN  [SAP, ERP, Excel, PowerPoint, Word, MBA, Bache...
#
# [44594 rows x 15 columns]

# %%
Jobs_csv.to_csv('jobs.csv', index=False, encoding="utf-16")
Jobs_csv.to_excel('jobs.xlsx', index=False)

# %% [markdown]
# # THANK YOU!!
