# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Files Loading

# %% [markdown]
# We load all the files in the folder "data":

# %%
folder = 'data_jobs'
files = os.listdir(folder)

dfs = []

headers = ['Job','URL','Company','Location','Salary','Posted','ID','Job_Description']

for file in files:
    path = os.path.join(folder, file)
    
    df = pd.read_excel(path, names=headers)
    
    dfs.append(df)

Jobs = pd.concat(dfs)

# %% [markdown]
# # Data Cleaning
#
# First of all, we need to delete all the duplicated values we could have. The best column to do so is the "ID" column:

# %%
Jobs = Jobs.drop_duplicates(subset='ID')

# %% [markdown]
# Let's see how it looks like the df:

# %%
Jobs.describe()
# Out:
#                       Job                                                URL  \
# count              105756                                             105756
# unique              47228                                             105756
# top     Financial Analyst  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# freq                 2968                                                  1
#
#                     Company Location                       Salary     Posted  \
# count                105707   105756                        44423      96571
# unique                32606    27175                        15373        176
# top     JPMorgan Chase & Co   Remote  $100,000 - $120,000 por año  PostedHoy
# freq                    492     5949                          328      35517
#
#                          ID                                    Job_Description
# count                105756                                             105756
# unique               105756                                             104375
# top     sj_1e37379f40861c74  Ir directamente al contenido principal_x000D_\...
# freq                      1                                                 19

# %%
Jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105756 entries, 0 to 987
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Job              105756 non-null  object
#  1   URL              105756 non-null  object
#  2   Company          105707 non-null  object
#  3   Location         105756 non-null  object
#  4   Salary           44423 non-null   object
#  5   Posted           96571 non-null   object
#  6   ID               105756 non-null  object
#  7   Job_Description  105756 non-null  object
# dtypes: object(8)
# memory usage: 7.3+ MB

# %% [markdown]
# We see we have almost all the columns with non-null values, except Salary and Posted. The column Posted is not critic, since it's a column that shows when the job posting was published in terms of the extraction date. It doesn't seem very useful, so we can't drop it.
#
# With regards to the Salary column, we see we have aprox 30-35% of non-null values.
# #### Could we estimate the Salary null values?
# Let's see it later!

# %%
Jobs.drop(columns=['Posted'])
# Out:
#                                                    Job  \
# 0                                     Business Analyst
# 1                         RPA Business Systems Analyst
# 2    Quantitive Business Analyst - Strategic Data S...
# 3    Business Line Product Lifecycle Management (PL...
# 4    Global Markets Operations Asset Services Ops S...
# ..                                                 ...
# 969         Property Controller- Graduate East Lansing
# 972                               Assistant Controller
# 980                                   Plant Controller
# 981                                         Controller
# 987                                   Plant Controller
#
#                                                    URL  \
# 0    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2    https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...
# 3    https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...
# 4    https://www.indeed.com/rc/clk?jk=0545baf656087...
# ..                                                 ...
# 969  https://www.indeed.com/rc/clk?jk=a88f74a87f1c6...
# 972  https://www.indeed.com/rc/clk?jk=6fe37642cf957...
# 980  https://www.indeed.com/rc/clk?jk=094beaf0996c9...
# 981  https://www.indeed.com/rc/clk?jk=f3027b081096f...
# 987  https://www.indeed.com/rc/clk?jk=f6fc5130f7639...
#
#                               Company  \
# 0                         CyberCoders
# 1                         Amerihealth
# 2                               Apple
# 3                  NXP Semiconductors
# 4                     Bank of America
# ..                                ...
# 969                 Schulte Companies
# 972  Home State Insurance Group, Inc.
# 980               Dometic Corporation
# 981             The Talance Group, LP
# 987                  Johnson Controls
#
#                                               Location  \
# 0                                 Torrington, CT 06790
# 1    Philadelphia, PA 19107 (City Center East area)...
# 2                                Austin, TX+1 location
# 3                      Austin, TX (West Oak Hill area)
# 4    Jacksonville, FL 32246 (Windy Hill area)+4 loc...
# ..                                                 ...
# 969                 East Lansing, MI 48823+1 ubicación
# 972                         Waco, TX 76710+1 ubicación
# 980                                 Cerritos, CA 90703
# 981                  Houston, TX 77002 (Downtown area)
# 987                        Marinette, WI+5 ubicaciones
#
#                          Salary                    ID  \
# 0    $80,000 - $110,000 por año   sj_1e37379f40861c74
# 1                           NaN   sj_a2789bdbc24f4aed
# 2                           NaN  job_15e7be7c9bf658e3
# 3                           NaN  job_e8519e1ec2d60a16
# 4                           NaN  job_0545baf6560877d1
# ..                          ...                   ...
# 969                         NaN  job_a88f74a87f1c6e48
# 972                         NaN  job_6fe37642cf95726f
# 980                         NaN  job_094beaf0996c95fe
# 981                         NaN  job_f3027b081096ff4c
# 987                         NaN  job_f6fc5130f7639a6e
#
#                                        Job_Description
# 0    Ir directamente al contenido principal_x000D_\...
# 1    Ir directamente al contenido principal_x000D_\...
# 2    Ir directamente al contenido principal_x000D_\...
# 3    Ir directamente al contenido principal_x000D_\...
# 4    Ir directamente al contenido principal_x000D_\...
# ..                                                 ...
# 969  Ir directamente al contenido principal_x000D_\...
# 972  Ir directamente al contenido principal_x000D_\...
# 980  Ir directamente al contenido principal_x000D_\...
# 981  Ir directamente al contenido principal_x000D_\...
# 987  Ir directamente al contenido principal_x000D_\...
#
# [105756 rows x 7 columns]

# %% [markdown]
# We saw all the Dtypes are object. However, the Salary column would be interesting to be a numeric column.

# %% [markdown]
# ## Salary

# %% [markdown]
# Let's see how it looks like:

# %%
Jobs['Salary'].head(50).values.tolist()
# Out:
# ['$80,000 - $110,000 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '$70,000 - $80,000 por año',
#  nan,
#  '$36 - $40 por hora',
#  'Hasta $176,800 por año',
#  nan,
#  nan,
#  '$70,000 - $129,000 por año',
#  nan,
#  '$55,000 - $75,000 por año',
#  '$56,400 - $94,000 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '$110,000 - $130,000 por año',
#  nan,
#  '$101,250 - $148,500 por año',
#  nan,
#  nan,
#  '$78,592 - $122,459 por año',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '$85,000 - $100,000 por año',
#  nan,
#  nan,
#  nan,
#  '$100,000 - $120,000 por año',
#  nan,
#  '$140,000 - $190,000 por año',
#  nan,
#  nan,
#  nan,
#  'Desde $58 por hora',
#  nan]

# %% [markdown]
# It looks horrible! We have single values, we have ranges, we have salary per year (año), month (mes), week (semana), day (día), and hourly (hora). Moreover we have the $ symbol in all the values, and in some cases we have the words Desde (From), and Hasta (Up to). Let's clean it!
#
# First of all, the frecuency pay could be interesting in order to standardize the salaries. Let's split it into a new column:

# %%
Jobs['Frecuency_Salary'] = Jobs['Salary'].str.split(' por ').str.get(1)

# %%
Jobs['Frecuency_Salary'].unique()
# Out:
# array(['año', nan, 'hora', 'mes', 'día', 'semana'], dtype=object)

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0                                   Business Analyst
# 1                       RPA Business Systems Analyst
# 2  Quantitive Business Analyst - Strategic Data S...
# 3  Business Line Product Lifecycle Management (PL...
# 4  Global Markets Operations Asset Services Ops S...
#
#                                                  URL             Company  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         CyberCoders
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         Amerihealth
# 2  https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...               Apple
# 3  https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...  NXP Semiconductors
# 4  https://www.indeed.com/rc/clk?jk=0545baf656087...     Bank of America
#
#                                             Location  \
# 0                               Torrington, CT 06790
# 1  Philadelphia, PA 19107 (City Center East area)...
# 2                              Austin, TX+1 location
# 3                    Austin, TX (West Oak Hill area)
# 4  Jacksonville, FL 32246 (Windy Hill area)+4 loc...
#
#                        Salary                  Posted                    ID  \
# 0  $80,000 - $110,000 por año  PostedRecién publicado   sj_1e37379f40861c74
# 1                         NaN  PostedRecién publicado   sj_a2789bdbc24f4aed
# 2                         NaN  PostedRecién publicado  job_15e7be7c9bf658e3
# 3                         NaN  PostedRecién publicado  job_e8519e1ec2d60a16
# 4                         NaN  PostedRecién publicado  job_0545baf6560877d1
#
#                                      Job_Description Frecuency_Salary
# 0  Ir directamente al contenido principal_x000D_\...              año
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              NaN
# 3  Ir directamente al contenido principal_x000D_\...              NaN
# 4  Ir directamente al contenido principal_x000D_\...              NaN

# %% [markdown]
# Nice! Now let's delete the words "Desde " and "Hasta ":

# %%
Jobs['Salary'] = Jobs['Salary'].str.replace('Desde ','')
Jobs['Salary'] = Jobs['Salary'].str.replace('Hasta ','')

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0                                   Business Analyst
# 1                       RPA Business Systems Analyst
# 2  Quantitive Business Analyst - Strategic Data S...
# 3  Business Line Product Lifecycle Management (PL...
# 4  Global Markets Operations Asset Services Ops S...
#
#                                                  URL             Company  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         CyberCoders
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         Amerihealth
# 2  https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...               Apple
# 3  https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...  NXP Semiconductors
# 4  https://www.indeed.com/rc/clk?jk=0545baf656087...     Bank of America
#
#                                             Location  \
# 0                               Torrington, CT 06790
# 1  Philadelphia, PA 19107 (City Center East area)...
# 2                              Austin, TX+1 location
# 3                    Austin, TX (West Oak Hill area)
# 4  Jacksonville, FL 32246 (Windy Hill area)+4 loc...
#
#                        Salary                  Posted                    ID  \
# 0  $80,000 - $110,000 por año  PostedRecién publicado   sj_1e37379f40861c74
# 1                         NaN  PostedRecién publicado   sj_a2789bdbc24f4aed
# 2                         NaN  PostedRecién publicado  job_15e7be7c9bf658e3
# 3                         NaN  PostedRecién publicado  job_e8519e1ec2d60a16
# 4                         NaN  PostedRecién publicado  job_0545baf6560877d1
#
#                                      Job_Description Frecuency_Salary
# 0  Ir directamente al contenido principal_x000D_\...              año
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              NaN
# 3  Ir directamente al contenido principal_x000D_\...              NaN
# 4  Ir directamente al contenido principal_x000D_\...              NaN

# %% [markdown]
# Let's work on the range values. An interesting approach would be to have two new columns, for the low part of the range, and another for the high part of the range:

# %%
salary_split = Jobs['Salary'].str.split('-', expand=True)
Jobs['Low_Salary'] = salary_split[0].str.strip()
Jobs['High_Salary'] = salary_split[1].str.strip()

# %% [markdown]
# With these split, all the non-range values, will have value only in the Low_Salary column. In this cases, let's set the same values for all low and high salary columns:

# %%
Jobs['High_Salary'] = Jobs['High_Salary'].fillna(Jobs['Low_Salary'])

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0                                   Business Analyst
# 1                       RPA Business Systems Analyst
# 2  Quantitive Business Analyst - Strategic Data S...
# 3  Business Line Product Lifecycle Management (PL...
# 4  Global Markets Operations Asset Services Ops S...
#
#                                                  URL             Company  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         CyberCoders
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         Amerihealth
# 2  https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...               Apple
# 3  https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...  NXP Semiconductors
# 4  https://www.indeed.com/rc/clk?jk=0545baf656087...     Bank of America
#
#                                             Location  \
# 0                               Torrington, CT 06790
# 1  Philadelphia, PA 19107 (City Center East area)...
# 2                              Austin, TX+1 location
# 3                    Austin, TX (West Oak Hill area)
# 4  Jacksonville, FL 32246 (Windy Hill area)+4 loc...
#
#                        Salary                  Posted                    ID  \
# 0  $80,000 - $110,000 por año  PostedRecién publicado   sj_1e37379f40861c74
# 1                         NaN  PostedRecién publicado   sj_a2789bdbc24f4aed
# 2                         NaN  PostedRecién publicado  job_15e7be7c9bf658e3
# 3                         NaN  PostedRecién publicado  job_e8519e1ec2d60a16
# 4                         NaN  PostedRecién publicado  job_0545baf6560877d1
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              año
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              NaN
# 3  Ir directamente al contenido principal_x000D_\...              NaN
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#   Low_Salary       High_Salary
# 0    $80,000  $110,000 por año
# 1        NaN               NaN
# 2        NaN               NaN
# 3        NaN               NaN
# 4        NaN               NaN

# %% [markdown]
# We see how it looks better, but we need to clean the non numeric values for both columns. So let's replace all the non numeric strings:

# %%
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace('[\$,]', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace('[\$,]', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por hora', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por hora', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por día', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por día', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por año', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por año', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por mes', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por mes', '', regex=True)
Jobs['Low_Salary'] = Jobs['Low_Salary'].replace(' por semana', '', regex=True)
Jobs['High_Salary'] = Jobs['High_Salary'].replace(' por semana', '', regex=True)

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0                                   Business Analyst
# 1                       RPA Business Systems Analyst
# 2  Quantitive Business Analyst - Strategic Data S...
# 3  Business Line Product Lifecycle Management (PL...
# 4  Global Markets Operations Asset Services Ops S...
#
#                                                  URL             Company  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         CyberCoders
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         Amerihealth
# 2  https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...               Apple
# 3  https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...  NXP Semiconductors
# 4  https://www.indeed.com/rc/clk?jk=0545baf656087...     Bank of America
#
#                                             Location  \
# 0                               Torrington, CT 06790
# 1  Philadelphia, PA 19107 (City Center East area)...
# 2                              Austin, TX+1 location
# 3                    Austin, TX (West Oak Hill area)
# 4  Jacksonville, FL 32246 (Windy Hill area)+4 loc...
#
#                        Salary                  Posted                    ID  \
# 0  $80,000 - $110,000 por año  PostedRecién publicado   sj_1e37379f40861c74
# 1                         NaN  PostedRecién publicado   sj_a2789bdbc24f4aed
# 2                         NaN  PostedRecién publicado  job_15e7be7c9bf658e3
# 3                         NaN  PostedRecién publicado  job_e8519e1ec2d60a16
# 4                         NaN  PostedRecién publicado  job_0545baf6560877d1
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              año
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              NaN
# 3  Ir directamente al contenido principal_x000D_\...              NaN
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#   Low_Salary High_Salary
# 0      80000      110000
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %% [markdown]
# Good! Now we need to standardize the Salaries, into a unique frecuency. The most common is to show the salary yearly. So let's transform all the non-yearly salaries into a yearly:

# %%
Jobs['Low_Salary'] = Jobs['Low_Salary'].astype(float)
Jobs['High_Salary'] = Jobs['High_Salary'].astype(float)

# %%
def transform_salary(row):
    if row['Frecuency_Salary'] == 'año':
        factor = 1
    elif row['Frecuency_Salary'] == 'mes':
        factor = 12
    elif row['Frecuency_Salary'] == 'semana':
        factor = 49
    elif row['Frecuency_Salary'] == 'día':
        factor = 230
    elif row['Frecuency_Salary'] == 'hora':
        factor = 1840
    else:
        factor = 1
    row['Low_Salary'] *= factor
    row['High_Salary'] *= factor
    return row

Jobs = Jobs.apply(transform_salary, axis=1)

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0                                   Business Analyst
# 1                       RPA Business Systems Analyst
# 2  Quantitive Business Analyst - Strategic Data S...
# 3  Business Line Product Lifecycle Management (PL...
# 4  Global Markets Operations Asset Services Ops S...
#
#                                                  URL             Company  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         CyberCoders
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         Amerihealth
# 2  https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...               Apple
# 3  https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...  NXP Semiconductors
# 4  https://www.indeed.com/rc/clk?jk=0545baf656087...     Bank of America
#
#                                             Location  \
# 0                               Torrington, CT 06790
# 1  Philadelphia, PA 19107 (City Center East area)...
# 2                              Austin, TX+1 location
# 3                    Austin, TX (West Oak Hill area)
# 4  Jacksonville, FL 32246 (Windy Hill area)+4 loc...
#
#                        Salary                  Posted                    ID  \
# 0  $80,000 - $110,000 por año  PostedRecién publicado   sj_1e37379f40861c74
# 1                         NaN  PostedRecién publicado   sj_a2789bdbc24f4aed
# 2                         NaN  PostedRecién publicado  job_15e7be7c9bf658e3
# 3                         NaN  PostedRecién publicado  job_e8519e1ec2d60a16
# 4                         NaN  PostedRecién publicado  job_0545baf6560877d1
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              año
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              NaN
# 3  Ir directamente al contenido principal_x000D_\...              NaN
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#    Low_Salary  High_Salary
# 0     80000.0     110000.0
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN

# %% [markdown]
# Nice! The last step here, is to create a unique column with salaries. The purpose of this is to compare and analyze, since some of the salaries are ranges and some others are not. The best approach for this is to have a mean salary column:

# %%
Jobs['Mean_Salary'] = (Jobs['Low_Salary'] + Jobs['High_Salary']) / 2

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0                                   Business Analyst
# 1                       RPA Business Systems Analyst
# 2  Quantitive Business Analyst - Strategic Data S...
# 3  Business Line Product Lifecycle Management (PL...
# 4  Global Markets Operations Asset Services Ops S...
#
#                                                  URL             Company  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         CyberCoders
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         Amerihealth
# 2  https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...               Apple
# 3  https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...  NXP Semiconductors
# 4  https://www.indeed.com/rc/clk?jk=0545baf656087...     Bank of America
#
#                                             Location  \
# 0                               Torrington, CT 06790
# 1  Philadelphia, PA 19107 (City Center East area)...
# 2                              Austin, TX+1 location
# 3                    Austin, TX (West Oak Hill area)
# 4  Jacksonville, FL 32246 (Windy Hill area)+4 loc...
#
#                        Salary                  Posted                    ID  \
# 0  $80,000 - $110,000 por año  PostedRecién publicado   sj_1e37379f40861c74
# 1                         NaN  PostedRecién publicado   sj_a2789bdbc24f4aed
# 2                         NaN  PostedRecién publicado  job_15e7be7c9bf658e3
# 3                         NaN  PostedRecién publicado  job_e8519e1ec2d60a16
# 4                         NaN  PostedRecién publicado  job_0545baf6560877d1
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              año
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              NaN
# 3  Ir directamente al contenido principal_x000D_\...              NaN
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#    Low_Salary  High_Salary  Mean_Salary
# 0     80000.0     110000.0      95000.0
# 1         NaN          NaN          NaN
# 2         NaN          NaN          NaN
# 3         NaN          NaN          NaN
# 4         NaN          NaN          NaN

# %% [markdown]
# PERFECT!

# %% [markdown]
# ## Jobs Group
#
# Since the Job names are quite heterogeneus, it's mandatory to group them in a few job groups. Let's do it with the dictionary categories.xlsx:

# %%
category_df = pd.read_excel('master_data\categories.xlsx')

category_df.head()
# Out:
#             keyword        category
# 0     data engineer   Data Engineer
# 1    data scientist  Data Scientist
# 2      data science  Data Scientist
# 3               ds   Data Scientist
# 4  machine learning  ML/AI Engineer

# %%
categories = category_df.set_index('keyword')['category'].to_dict()

def assign_category(job):
    job = job.lower()
    for keyword, category in categories.items():
        if keyword in job:
            return category
    return 'Others'

Jobs['Jobs_Group'] = Jobs['Job'].apply(assign_category)

# %%
category_counts = Jobs['Jobs_Group'].value_counts()

print(category_counts)
# Out:
# Financial Analyst            18143
# Business Analyst             16346
# Data Analyst                 12413
# Data Engineer                10061
# Controller                    9868
# Data Scientist                7048
# Business Intelligence         6088
# CFO                           5472
# Analyst                       5352
# Finance                       5346
# Operations Analyst            3508
# Others                        2624
# ML/AI Engineer                2589
# Statistician/Mathemathics      898
# Name: Jobs_Group, dtype: int64

# %% [markdown]
# Nice!

# %% [markdown]
# ## Location

# %% [markdown]
# The next step would be to clean the Location column. Would be nice to have a City and State column. The best way to split it, is to split it two columns by comma, getting all the string before, and the two letters after comma. The first column will be the city, and the second one the state. Let's work on it!

# %%
Jobs[['City', 'State']] = Jobs['Location'].str.extract(r'^(.+),\s([A-Z]{2})', expand=True)

# %%
Jobs.head()
# Out:
#                                                  Job  \
# 0                                   Business Analyst
# 1                       RPA Business Systems Analyst
# 2  Quantitive Business Analyst - Strategic Data S...
# 3  Business Line Product Lifecycle Management (PL...
# 4  Global Markets Operations Asset Services Ops S...
#
#                                                  URL             Company  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         CyberCoders
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...         Amerihealth
# 2  https://www.indeed.com/rc/clk?jk=15e7be7c9bf65...               Apple
# 3  https://www.indeed.com/rc/clk?jk=e8519e1ec2d60...  NXP Semiconductors
# 4  https://www.indeed.com/rc/clk?jk=0545baf656087...     Bank of America
#
#                                             Location  \
# 0                               Torrington, CT 06790
# 1  Philadelphia, PA 19107 (City Center East area)...
# 2                              Austin, TX+1 location
# 3                    Austin, TX (West Oak Hill area)
# 4  Jacksonville, FL 32246 (Windy Hill area)+4 loc...
#
#                        Salary                  Posted                    ID  \
# 0  $80,000 - $110,000 por año  PostedRecién publicado   sj_1e37379f40861c74
# 1                         NaN  PostedRecién publicado   sj_a2789bdbc24f4aed
# 2                         NaN  PostedRecién publicado  job_15e7be7c9bf658e3
# 3                         NaN  PostedRecién publicado  job_e8519e1ec2d60a16
# 4                         NaN  PostedRecién publicado  job_0545baf6560877d1
#
#                                      Job_Description Frecuency_Salary  \
# 0  Ir directamente al contenido principal_x000D_\...              año
# 1  Ir directamente al contenido principal_x000D_\...              NaN
# 2  Ir directamente al contenido principal_x000D_\...              NaN
# 3  Ir directamente al contenido principal_x000D_\...              NaN
# 4  Ir directamente al contenido principal_x000D_\...              NaN
#
#    Low_Salary  High_Salary  Mean_Salary          Jobs_Group          City  \
# 0     80000.0     110000.0      95000.0    Business Analyst    Torrington
# 1         NaN          NaN          NaN    Business Analyst  Philadelphia
# 2         NaN          NaN          NaN    Business Analyst        Austin
# 3         NaN          NaN          NaN    Business Analyst        Austin
# 4         NaN          NaN          NaN  Operations Analyst  Jacksonville
#
#   State
# 0    CT
# 1    PA
# 2    TX
# 3    TX
# 4    FL

# %%
Jobs['City'].values
# Out:
# array(['Torrington', 'Philadelphia', 'Austin', ..., 'Cerritos', 'Houston',
#        'Marinette'], dtype=object)

# %%
Jobs['State'].values
# Out:
# array(['CT', 'PA', 'TX', ..., 'CA', 'TX', 'WI'], dtype=object)

# %% [markdown]
# Nice! Now a minor problem, is that there is some Locations, that are directy the state (e.g. California). In this cases, let's create a function, using the dictionary states.xlsx:

# %%
states_df = pd.read_excel('master_data\states.xlsx')

states_df.head()
# Out:
#         State Code
# 0     Alabama   AL
# 1      Alaska   AK
# 2     Arizona   AZ
# 3    Arkansas   AR
# 4  California   CA

# %%
states_dict = states_df.set_index('State')['Code'].to_dict()

def assign_state(row):
    if pd.isnull(row['State']):
        for state, code in states_dict.items():
            if state.lower() in row['Location'].lower():
                return code
    return row['State']

Jobs['State'] = Jobs.apply(assign_state, axis=1)

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Remote
#
# An interesting column would be if a job is remote or hybrid or none of these. In order to do so, we can use a dictionary with keywords:

# %%
remote_df = pd.read_excel('master_data/remote.xlsx')

remote_df.head()
# Out:
#             Value Category
# 0          Remote   Remote
# 1          remote   Remote
# 2          Hybrid   Hybrid
# 3          hybrid   Hybrid
# 4  Work From Home   Remote

# %%
remote_dict = remote_df.set_index('Value')['Category'].to_dict()

def assign_remote(row):
    for col in ['Job', 'Location', 'Job_Description']:
        for value, category in remote_dict.items():
            if value.lower() in row[col].lower():
                return category
    return None

Jobs['Remote'] = Jobs.apply(assign_remote, axis=1)

# %%
remote_counts = Jobs['Remote'].value_counts()

print(remote_counts)
# Out:
# Remote    29981
# Hybrid    10993
# Name: Remote, dtype: int64

# %% [markdown]
# Looks great!

# %% [markdown]
# ## Profile
#
# Another interesting column is the profile. In this column we will show if it's a Lead, Senior or a Junior position. As we did in the remote column, we will use a dictionary:

# %%
profile_df = pd.read_excel('master_data\profile.xlsx')

profile_df.head()
# Out:
#     Value Profile
# 0  junior  Junior
# 1  Junior  Junior
# 2      Jr  Junior
# 3     Jr.  Junior
# 4  senior  Senior

# %%
profile_dict = profile_df.set_index('Value')['Profile'].to_dict()

def assign_profile(row):
    for col in ['Job']:
        for value, profile in profile_dict.items():
            if value.lower() in row[col].lower():
                return profile
    return None

Jobs['Profile'] = Jobs.apply(assign_profile, axis=1)

# %%
profile_counts = Jobs['Profile'].value_counts()

print(profile_counts)
# Out:
# Senior    20848
# Lead      16572
# Junior     1293
# Name: Profile, dtype: int64

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Skills
#
# Now, let's deep into the job descriptions. Would be nice to have a Skills column. We can have it using a dictionary skills.xlsx:

# %%
skills_df = pd.read_excel('master_data\skills.xlsx')

skills_df.head()
# Out:
#                 Skills            Group
# 0               Access           Access
# 1      Adobe Analytics  Adobe Analytics
# 2                  AWS              AWS
# 3  Amazon Web Services              AWS
# 4           Amazon Web              AWS

# %%
skills_dict = skills_df.set_index('Skills')['Group'].to_dict()

Jobs['Skills'] = Jobs['Job_Description'].apply(lambda x: list(set([skills_dict[skill] for skill in skills_dict.keys() if skill in x])))

# %%
skills_freq = Jobs['Skills'].explode().value_counts()

skills_percent = skills_freq / len(Jobs) * 100

top_skills = skills_percent.sort_values(ascending=False)

skills_df_freq = pd.DataFrame({'Percentage': top_skills, 'Count': skills_freq[top_skills.index]})

skills_df_freq.style.format({'Percentage': '{:.2f}%'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_57b65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57b65_level0_col0" class="col_heading level0 col0" >Percentage</th>
#       <th id="T_57b65_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57b65_level0_row0" class="row_heading level0 row0" >Bachelor</th>
#       <td id="T_57b65_row0_col0" class="data row0 col0" >65.49%</td>
#       <td id="T_57b65_row0_col1" class="data row0 col1" >69263</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row1" class="row_heading level0 row1" >Office</th>
#       <td id="T_57b65_row1_col0" class="data row1 col0" >33.81%</td>
#       <td id="T_57b65_row1_col1" class="data row1 col1" >35752</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row2" class="row_heading level0 row2" >Excel</th>
#       <td id="T_57b65_row2_col0" class="data row2 col0" >28.63%</td>
#       <td id="T_57b65_row2_col1" class="data row2 col1" >30275</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row3" class="row_heading level0 row3" >SQL</th>
#       <td id="T_57b65_row3_col0" class="data row3 col0" >28.42%</td>
#       <td id="T_57b65_row3_col1" class="data row3 col1" >30058</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row4" class="row_heading level0 row4" >Python</th>
#       <td id="T_57b65_row4_col0" class="data row4 col0" >18.80%</td>
#       <td id="T_57b65_row4_col1" class="data row4 col1" >19882</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row5" class="row_heading level0 row5" >Master</th>
#       <td id="T_57b65_row5_col0" class="data row5 col0" >18.49%</td>
#       <td id="T_57b65_row5_col1" class="data row5 col1" >19559</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row6" class="row_heading level0 row6" >Tableau</th>
#       <td id="T_57b65_row6_col0" class="data row6 col0" >12.77%</td>
#       <td id="T_57b65_row6_col1" class="data row6 col1" >13501</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row7" class="row_heading level0 row7" >Word</th>
#       <td id="T_57b65_row7_col0" class="data row7 col0" >12.58%</td>
#       <td id="T_57b65_row7_col1" class="data row7 col1" >13307</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row8" class="row_heading level0 row8" >Power BI</th>
#       <td id="T_57b65_row8_col0" class="data row8 col0" >12.51%</td>
#       <td id="T_57b65_row8_col1" class="data row8 col1" >13227</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row9" class="row_heading level0 row9" >PowerPoint</th>
#       <td id="T_57b65_row9_col0" class="data row9 col0" >12.47%</td>
#       <td id="T_57b65_row9_col1" class="data row9 col1" >13193</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row10" class="row_heading level0 row10" >CPA</th>
#       <td id="T_57b65_row10_col0" class="data row10 col0" >12.00%</td>
#       <td id="T_57b65_row10_col1" class="data row10 col1" >12689</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row11" class="row_heading level0 row11" >Agile</th>
#       <td id="T_57b65_row11_col0" class="data row11 col0" >8.03%</td>
#       <td id="T_57b65_row11_col1" class="data row11 col1" >8490</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row12" class="row_heading level0 row12" >ERP</th>
#       <td id="T_57b65_row12_col0" class="data row12 col0" >7.75%</td>
#       <td id="T_57b65_row12_col1" class="data row12 col1" >8193</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row13" class="row_heading level0 row13" >Access</th>
#       <td id="T_57b65_row13_col0" class="data row13 col0" >7.57%</td>
#       <td id="T_57b65_row13_col1" class="data row13 col1" >8001</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row14" class="row_heading level0 row14" >AWS</th>
#       <td id="T_57b65_row14_col0" class="data row14 col0" >7.54%</td>
#       <td id="T_57b65_row14_col1" class="data row14 col1" >7977</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row15" class="row_heading level0 row15" >SAP</th>
#       <td id="T_57b65_row15_col0" class="data row15 col0" >7.00%</td>
#       <td id="T_57b65_row15_col1" class="data row15 col1" >7407</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row16" class="row_heading level0 row16" >R</th>
#       <td id="T_57b65_row16_col0" class="data row16 col0" >6.78%</td>
#       <td id="T_57b65_row16_col1" class="data row16 col1" >7167</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row17" class="row_heading level0 row17" >Azure</th>
#       <td id="T_57b65_row17_col0" class="data row17 col0" >6.27%</td>
#       <td id="T_57b65_row17_col1" class="data row17 col1" >6636</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row18" class="row_heading level0 row18" >Oracle</th>
#       <td id="T_57b65_row18_col0" class="data row18 col0" >6.24%</td>
#       <td id="T_57b65_row18_col1" class="data row18 col1" >6597</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row19" class="row_heading level0 row19" >MBA</th>
#       <td id="T_57b65_row19_col0" class="data row19 col0" >5.80%</td>
#       <td id="T_57b65_row19_col1" class="data row19 col1" >6129</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row20" class="row_heading level0 row20" >Artificial Intelligence</th>
#       <td id="T_57b65_row20_col0" class="data row20 col0" >5.63%</td>
#       <td id="T_57b65_row20_col1" class="data row20 col1" >5958</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row21" class="row_heading level0 row21" >English</th>
#       <td id="T_57b65_row21_col0" class="data row21 col0" >4.95%</td>
#       <td id="T_57b65_row21_col1" class="data row21 col1" >5234</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row22" class="row_heading level0 row22" >Spark</th>
#       <td id="T_57b65_row22_col0" class="data row22 col0" >4.87%</td>
#       <td id="T_57b65_row22_col1" class="data row22 col1" >5146</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row23" class="row_heading level0 row23" >Machine Learning</th>
#       <td id="T_57b65_row23_col0" class="data row23 col0" >4.71%</td>
#       <td id="T_57b65_row23_col1" class="data row23 col1" >4981</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row24" class="row_heading level0 row24" >Java</th>
#       <td id="T_57b65_row24_col0" class="data row24 col0" >3.77%</td>
#       <td id="T_57b65_row24_col1" class="data row24 col1" >3989</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row25" class="row_heading level0 row25" >PhD</th>
#       <td id="T_57b65_row25_col0" class="data row25 col0" >3.08%</td>
#       <td id="T_57b65_row25_col1" class="data row25 col1" >3259</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row26" class="row_heading level0 row26" >Salesforce</th>
#       <td id="T_57b65_row26_col0" class="data row26 col0" >3.05%</td>
#       <td id="T_57b65_row26_col1" class="data row26 col1" >3221</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row27" class="row_heading level0 row27" >Hadoop</th>
#       <td id="T_57b65_row27_col0" class="data row27 col0" >2.75%</td>
#       <td id="T_57b65_row27_col1" class="data row27 col1" >2909</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row28" class="row_heading level0 row28" >Tensor Flow</th>
#       <td id="T_57b65_row28_col0" class="data row28 col0" >2.15%</td>
#       <td id="T_57b65_row28_col1" class="data row28 col1" >2276</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row29" class="row_heading level0 row29" >C++</th>
#       <td id="T_57b65_row29_col0" class="data row29 col0" >2.13%</td>
#       <td id="T_57b65_row29_col1" class="data row29 col1" >2253</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row30" class="row_heading level0 row30" >Databricks</th>
#       <td id="T_57b65_row30_col0" class="data row30 col0" >2.10%</td>
#       <td id="T_57b65_row30_col1" class="data row30 col1" >2220</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level0_row31" class="row_heading level0 row31" >HTML</th>
#       <td id="T_57b65_row31_col0" class="data row31 col0" >2.05%</td>
#       <td id="T_57b65_row31_col1" class="data row31 col1" >2165</td>
#     </tr>
#     <tr>
#       <th id="T_57b65_level

# %% [markdown]
# Perfect!

# %% [markdown]
# # Generating the csv file
#
# The last part is generate the final file. We are going to generate a csv format file. But first of all, we need to reorganize the columns:

# %%
Jobs_csv = Jobs[['ID','Job','Jobs_Group','Profile','Remote','Company','Location','City','State','Salary','Frecuency_Salary','Low_Salary','High_Salary','Mean_Salary','Skills']]

# %%
Jobs_csv
# Out:
#                        ID                                                Job  \
# 0     sj_1e37379f40861c74                                   Business Analyst
# 1     sj_a2789bdbc24f4aed                       RPA Business Systems Analyst
# 2    job_15e7be7c9bf658e3  Quantitive Business Analyst - Strategic Data S...
# 3    job_e8519e1ec2d60a16  Business Line Product Lifecycle Management (PL...
# 4    job_0545baf6560877d1  Global Markets Operations Asset Services Ops S...
# ..                    ...                                                ...
# 969  job_a88f74a87f1c6e48         Property Controller- Graduate East Lansing
# 972  job_6fe37642cf95726f                               Assistant Controller
# 980  job_094beaf0996c95fe                                   Plant Controller
# 981  job_f3027b081096ff4c                                         Controller
# 987  job_f6fc5130f7639a6e                                   Plant Controller
#
#              Jobs_Group Profile  Remote                           Company  \
# 0      Business Analyst    None    None                       CyberCoders
# 1      Business Analyst    None    None                       Amerihealth
# 2      Business Analyst    None    None                             Apple
# 3      Business Analyst  Junior    None                NXP Semiconductors
# 4    Operations Analyst  Senior    None                   Bank of America
# ..                  ...     ...     ...                               ...
# 969          Controller    None    None                 Schulte Companies
# 972          Controller    None    None  Home State Insurance Group, Inc.
# 980          Controller    None    None               Dometic Corporation
# 981          Controller    None  Remote             The Talance Group, LP
# 987          Controller    None    None                  Johnson Controls
#
#                                               Location          City State  \
# 0                                 Torrington, CT 06790    Torrington    CT
# 1    Philadelphia, PA 19107 (City Center East area)...  Philadelphia    PA
# 2                                Austin, TX+1 location        Austin    TX
# 3                      Austin, TX (West Oak Hill area)        Austin    TX
# 4    Jacksonville, FL 32246 (Windy Hill area)+4 loc...  Jacksonville    FL
# ..                                                 ...           ...   ...
# 969                 East Lansing, MI 48823+1 ubicación  East Lansing    MI
# 972                         Waco, TX 76710+1 ubicación          Waco    TX
# 980                                 Cerritos, CA 90703      Cerritos    CA
# 981                  Houston, TX 77002 (Downtown area)       Houston    TX
# 987                        Marinette, WI+5 ubicaciones     Marinette    WI
#
#                          Salary Frecuency_Salary  Low_Salary  High_Salary  \
# 0    $80,000 - $110,000 por año              año     80000.0     110000.0
# 1                           NaN              NaN         NaN          NaN
# 2                           NaN              NaN         NaN          NaN
# 3                           NaN              NaN         NaN          NaN
# 4                           NaN              NaN         NaN          NaN
# ..                          ...              ...         ...          ...
# 969                         NaN              NaN         NaN          NaN
# 972                         NaN              NaN         NaN          NaN
# 980                         NaN              NaN         NaN          NaN
# 981                         NaN              NaN         NaN          NaN
# 987                         NaN              NaN         NaN          NaN
#
#      Mean_Salary                                             Skills
# 0        95000.0                                                 []
# 1            NaN                            [Office, SQL, Bachelor]
# 2            NaN                            [Python, SQL, Bachelor]
# 3            NaN                                         [Bachelor]
# 4            NaN                                            [Excel]
# ..           ...                                                ...
# 969          NaN                                 [Office, Bachelor]
# 972          NaN                    [Excel, Word, Office, Bachelor]
# 980          NaN  [Excel, Access, Office, Bachelor, PowerPoint, ...
# 981          NaN                                              [CPA]
# 987          NaN  [Excel, MBA, Word, Bachelor, PowerPoint, SAP, ...
#
# [105756 rows x 15 columns]

# %%
Jobs_csv.to_csv('jobs.csv', index=False, encoding="utf-16")
Jobs_csv.to_excel('jobs.xlsx', index=False)

# %% [markdown]
# # THANK YOU!!
